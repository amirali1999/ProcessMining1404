# %%
# !pip install --upgrade pm4py

# %%
import pm4py
from pm4py.algo.conformance.tokenreplay import algorithm as token_replay
from pm4py.objects.petri_net.importer import importer as petri_importer  
from pm4py.visualization.petri_net import visualizer as petri_visualizer  
import pandas as pd
import os
import json
def load_pnml_model(pnml_file_path):
    net, initial_marking, final_marking = petri_importer.apply(pnml_file_path)
    return net, initial_marking, final_marking

def load_csv_log(csv_file_path):
    df = pd.read_csv(csv_file_path)
    log = pm4py.format_dataframe(df, timestamp_key="time:timestamp")
    return log, df

def apply_token_replay(log, net, initial_marking, final_marking):
    replayed_traces = token_replay.apply(log, net, initial_marking, final_marking)
    return replayed_traces


def check_for_anomalies(replayed_traces, df):
    case_names = df['case:concept:name'].unique()
    compliant_cases = []
    non_compliant_cases = []
    
    for i, trace_result in enumerate(replayed_traces):
        current_case_name = case_names[i]
        case_data = df[df['case:concept:name'] == current_case_name]
        
        if not trace_result['trace_is_fit']:
            print(f"Anomaly detected in case '{current_case_name}'.")
            non_compliant_cases.append(case_data)
        else:
            print(f"Case '{current_case_name}' is compliant.")
            compliant_cases.append(case_data)
    
    return compliant_cases, non_compliant_cases

def calculate_compliance_percentage(replayed_traces):
    total_cases = len(replayed_traces)
    compliant_cases = sum([1 for trace_result in replayed_traces if trace_result['trace_is_fit']])
    non_compliant_cases = total_cases - compliant_cases

    compliant_percentage = (compliant_cases / total_cases) * 100
    non_compliant_percentage = (non_compliant_cases / total_cases) * 100

    print(f"Total cases: {total_cases}")
    print(f"Compliant cases: {compliant_cases} ({compliant_percentage:.2f}%)")
    print(f"Non-compliant cases: {non_compliant_cases} ({non_compliant_percentage:.2f}%)")

    return {
        "total_cases": total_cases,
        "compliant_cases": compliant_cases,
        "non_compliant_cases": non_compliant_cases,
        "compliant_percentage": compliant_percentage,
        "non_compliant_percentage": non_compliant_percentage,
    }

def save_pnml_model_as_png(net, initial_marking, final_marking, png_output_path):
    gviz = petri_visualizer.apply(net, initial_marking, final_marking)
    petri_visualizer.save(gviz,"data/"+png_output_path +".png")
    print(f"Petri Net model saved as PNG at: {png_output_path}.png")


def save_results_to_csv(compliant_cases, non_compliant_cases, output_file_path):
    compliant_df = pd.concat(compliant_cases)
    non_compliant_df = pd.concat(non_compliant_cases)

    # ذخیره به فایل CSV
    compliant_df.to_csv("data/compliant_"+output_file_path + ".csv", index=False)
    non_compliant_df.to_csv("data/non_compliant_"+output_file_path + ".csv", index=False)

    print(f"Compliant cases saved to {output_file_path}_compliant.csv")
    print(f"Non-compliant cases saved to {output_file_path}_non_compliant.csv")


def process_log(pnml_file_path, csv_file_path):

    pnml_file_name = os.path.splitext(os.path.basename(pnml_file_path))[0]
    csv_file_name = os.path.splitext(os.path.basename(csv_file_path))[0]
    output_file_base_name = f"{pnml_file_name}_{csv_file_name}"

    net, initial_marking, final_marking = load_pnml_model(pnml_file_path)
    
    log, df = load_csv_log(csv_file_path)
    
    replayed_traces = apply_token_replay(log, net, initial_marking, final_marking)
    
    compliant_cases, non_compliant_cases = check_for_anomalies(replayed_traces, df)
    
    stats = calculate_compliance_percentage(replayed_traces)
    
    summary = {
        "model_file": os.path.basename(pnml_file_path),
        "log_file": os.path.basename(csv_file_path),
        "stats": stats
    }

    summary_file_path = "data/"+output_file_base_name + "_summary.json"
    with open(summary_file_path, "w", encoding="utf-8") as f:
        json.dump(summary, f, indent=4, ensure_ascii=False)

    print(f"Summary saved to {summary_file_path}")

    save_results_to_csv(compliant_cases, non_compliant_cases, output_file_base_name)
    
    save_pnml_model_as_png(net, initial_marking, final_marking, output_file_base_name)

# %%
pnml_file_path = "./data/heuristic_SP_DF_cleaned.pnml"  
log_csv_file_path = "./data/SP_DF_cleaned.csv"  
process_log(pnml_file_path, log_csv_file_path)
# Out:
# replaying log with TBR, completed traces :: 100%|██████████| 1028/1028 [00:02<00:00, 469.13it/s]
# Case '1' is compliant.
# Anomaly detected in case '2'.
# Case '3' is compliant.
# Anomaly detected in case '4'.
# Case '5' is compliant.
# Case '6' is compliant.
# Anomaly detected in case '7'.
# Case '8' is compliant.
# Anomaly detected in case '9'.
# Case '10' is compliant.
# Case '11' is compliant.
# Case '12' is compliant.
# Anomaly detected in case '13'.
# Anomaly detected in case '14'.
# Anomaly detected in case '15'.
# Case '16' is compliant.
# Anomaly detected in case '17'.
# Case '18' is compliant.
# Anomaly detected in case '19'.
# Anomaly detected in case '20'.
# Case '21' is compliant.
# Case '22' is compliant.
# Anomaly detected in case '23'.
# Anomaly detected in case '24'.
# Case '25' is compliant.
# Anomaly detected in case '26'.
# Anomaly detected in case '27'.
# Anomaly detected in case '28'.
# Anomaly detected in case '29'.
# Case '30' is compliant.
# Case '31' is compliant.
# Case '32' is compliant.
# Case '33' is compliant.
# Anomaly detected in case '34'.
# Case '35' is compliant.
# Case '36' is compliant.
# Anomaly detected in case '37'.
# Case '38' is compliant.
# Case '39' is compliant.
# Anomaly detected in case '40'.
# Anomaly detected in case '41'.
# Case '42' is compliant.
# Case '43' is compliant.
# Anomaly detected in case '44'.
# Anomaly detected in case '45'.
# Anomaly detected in case '46'.
# Case '47' is compliant.
# Anomaly detected in case '48'.
# Case '49' is compliant.
# Anomaly detected in case '50'.
# Case '51' is compliant.
# Case '52' is compliant.
# Case '53' is compliant.
# Anomaly detected in case '54'.
# Anomaly detected in case '55'.
# Case '56' is compliant.
# Anomaly detected in case '57'.
# Case '58' is compliant.
# Case '59' is compliant.
# Anomaly detected in case '60'.
# Case '61' is compliant.
# Anomaly detected in case '62'.
# Case '63' is compliant.
# Case '64' is compliant.
# Anomaly detected in case '65'.
# Anomaly detected in case '66'.
# Anomaly detected in case '67'.
# Anomaly detected in case '68'.
# Anomaly detected in case '69'.
# Case '70' is compliant.
# Case '71' is compliant.
# Case '72' is compliant.
# Anomaly detected in case '73'.
# Anomaly detected in case '74'.
# Case '75' is compliant.
# Anomaly detected in case '76'.
# Case '77' is compliant.
# Anomaly detected in case '78'.
# Anomaly detected in case '79'.
# Case '80' is compliant.
# Case '81' is compliant.
# Case '82' is compliant.
# Case '83' is compliant.
# Anomaly detected in case '84'.
# Anomaly detected in case '85'.
# Anomaly detected in case '86'.
# Case '87' is compliant.
# Case '88' is compliant.
# Anomaly detected in case '89'.
# Anomaly detected in case '90'.
# Case '91' is compliant.
# Case '92' is compliant.
# Anomaly detected in case '93'.
# Anomaly detected in case '94'.
# Anomaly detected in case '95'.
# Anomaly detected in case '96'.
# Case '97' is compliant.
# Anomaly detected in case '98'.
# Case '99' is compliant.
# Anomaly detected in case '100'.
# Case '101' is compliant.
# Case '102' is compliant.
# Anomaly detected in case '103'.
# Anomaly detected in case '104'.
# Anomaly detected in case '105'.
# Anomaly detected in case '106'.
# Anomaly detected in case '107'.
# Anomaly detected in case '108'.
# Anomaly detected in case '109'.
# Anomaly detected in case '110'.
# Anomaly detected in case '111'.
# Case '112' is compliant.
# Anomaly detected in case '113'.
# Anomaly detected in case '114'.
# Case '115' is compliant.
# Anomaly detected in case '116'.
# Anomaly detected in case '117'.
# Anomaly detected in case '118'.
# Case '119' is compliant.
# Case '120' is compliant.
# Anomaly detected in case '121'.
# Case '122' is compliant.
# Anomaly detected in case '123'.
# Anomaly detected in case '124'.
# Anomaly detected in case '125'.
# Anomaly detected in case '126'.
# Case '127' is compliant.
# Anomaly detected in case '128'.
# Anomaly detected in case '129'.
# Anomaly detected in case '130'.
# Anomaly detected in case '131'.
# Anomaly detected in case '132'.
# Case '133' is compliant.
# Case '134' is compliant.
# Case '135' is compliant.
# Case '136' is compliant.
# Anomaly detected in case '137'.
# Anomaly detected in case '138'.
# Case '139' is compliant.
# Anomaly detected in case '140'.
# Anomaly detected in case '141'.
# Anomaly detected in case '142'.
# Case '143' is compliant.
# Anomaly detected in case '144'.
# Case '145' is compliant.
# Case '146' is compliant.
# Case '147' is compliant.
# Anomaly detected in case '148'.
# Case '149' is compliant.
# Case '150' is compliant.
# Anomaly detected in case '151'.
# Anomaly detected in case '152'.
# Anomaly detected in case '153'.
# Anomaly detected in case '154'.
# Anomaly detected in case '155'.
# Case '156' is compliant.
# Anomaly detected in case '157'.
# Anomaly detected in case '158'.
# Case '159' is compliant.
# Anomaly detected in case '160'.
# Anomaly detected in case '161'.
# Anomaly detected in case '162'.
# Case '163' is compliant.
# Case '164' is compliant.
# Case '165' is compliant.
# Anomaly detected in case '166'.
# Case '167' is compliant.
# Anomaly detected in case '168'.
# Case '169' is compliant.
# Case '170' is compliant.
# Case '171' is compliant.
# Case '172' is compliant.
# Anomaly detected in case '173'.
# Case '174' is compliant.
# Anomaly detected in case '175'.
# Case '176' is compliant.
# Case '177' is compliant.
# Case '178' is compliant.
# Anomaly detected in case '179'.
# Case '180' is compliant.
# Anomaly detected in case '181'.
# Anomaly detected in case '182'.
# Case '183' is compliant.
# Case '184' is compliant.
# Case '185' is compliant.
# Anomaly detected in case '186'.
# Case '187' is compliant.
# Case '188' is compliant.
# Case '189' is compliant.
# Anomaly detected in case '190'.
# Case '191' is compliant.
# Case '192' is compliant.
# Case '193' is compliant.
# Anomaly detected in case '194'.
# Case '195' is compliant.
# Case '196' is compliant.
# Case '197' is compliant.
# Anomaly detected in case '198'.
# Case '199' is compliant.
# Anomaly detected in case '200'.
# Anomaly detected in case '201'.
# Case '202' is compliant.
# Anomaly detected in case '203'.
# Anomaly detected in case '204'.
# Anomaly detected in case '205'.
# Anomaly detected in case '206'.
# Anomaly detected in case '207'.
# Case '208' is compliant.
# Anomaly detected in case '209'.
# Anomaly detected in case '210'.
# Case '211' is compliant.
# Case '212' is compliant.
# Anomaly detected in case '213'.
# Anomaly detected in case '214'.
# Anomaly detected in case '215'.
# Anomaly detected in case '216'.
# Case '217' is compliant.
# Case '218' is compliant.
# Case '219' is compliant.
# Anomaly detected in case '220'.
# Case '221' is compliant.
# Case '222' is compliant.
# Case '223' is compliant.
# Anomaly detected in case '224'.
# Anomaly detected in case '225'.
# Anomaly detected in case '226'.
# Anomaly detected in case '227'.
# Anomaly detected in case '228'.
# Case '229' is compliant.
# Anomaly detected in case '230'.
# Anomaly detected in case '231'.
# Case '232' is compliant.
# Case '233' is compliant.
# Case '234' is compliant.
# Case '235' is compliant.
# Anomaly detected in case '236'.
# Case '237' is compliant.
# Anomaly detected in case '238'.
# Case '239' is compliant.
# Case '240' is compliant.
# Case '241' is compliant.
# Anomaly detected in case '242'.
# Case '243' is compliant.
# Case '244' is compliant.
# Anomaly detected in case '245'.
# Anomaly detected in case '246'.
# Case '247' is compliant.
# Case '248' is compliant.
# Anomaly detected in case '249'.
# Case '250' is compliant.
# Case '251' is compliant.
# Case '252' is compliant.
# Anomaly detected in case '253'.
# Case '254' is compliant.
# Anomaly detected in case '255'.
# Case '256' is compliant.
# Anomaly detected in case '257'.
# Anomaly detected in case '258'.
# Case '259' is compliant.
# Case '260' is compliant.
# Case '261' is compliant.
# Anomaly detected in case '262'.
# Case '263' is compliant.
# Case '264' is compliant.
# Anomaly detected in case '265'.
# Case '266' is compliant.
# Case '267' is compliant.
# Anomaly detected in case '268'.
# Case '269' is compliant.
# Anomaly detected in case '270'.
# Anomaly detected in case '271'.
# Case '272' is compliant.
# Anomaly detected in case '273'.
# Anomaly detected in case '274'.
# Anomaly detected in case '275'.
# Anomaly detected in case '276'.
# Case '277' is compliant.
# Case '278' is compliant.
# Anomaly detected in case '279'.
# Case '280' is compliant.
# Case '281' is compliant.
# Anomaly detected in case '282'.
# Case '283' is compliant.
# Anomaly detected in case '284'.
# Anomaly detected in case '285'.
# Case '286' is compliant.
# Case '287' is compliant.
# Anomaly detected in case '288'.
# Anomaly detected in case '289'.
# Anomaly detected in case '290'.
# Anomaly detected in case '291'.
# Case '292' is compliant.
# Anomaly detected in case '293'.
# Anomaly detected in case '294'.
# Anomaly detected in case '295'.
# Case '296' is compliant.
# Case '297' is compliant.
# Anomaly detected in case '298'.
# Case '299' is compliant.
# Case '300' is compliant.
# Anomaly detected in case '301'.
# Anomaly detected in case '302'.
# Case '303' is compliant.
# Anomaly detected in case '304'.
# Case '305' is compliant.
# Anomaly detected in case '306'.
# Case '307' is compliant.
# Anomaly detected in case '308'.
# Anomaly detected in case '309'.
# Anomaly detected in case '310'.
# Anomaly detected in case '311'.
# Case '312' is compliant.
# Case '313' is compliant.
# Case '314' is compliant.
# Case '315' is compliant.
# Case '316' is compliant.
# Case '317' is compliant.
# Case '318' is compliant.
# Anomaly detected in case '319'.
# Case '320' is compliant.
# Case '321' is compliant.
# Anomaly detected in case '322'.
# Case '323' is compliant.
# Anomaly detected in case '324'.
# Anomaly detected in case '325'.
# Anomaly detected in case '326'.
# Case '327' is compliant.
# Anomaly detected in case '328'.
# Case '329' is compliant.
# Anomaly detected in case '330'.
# Anomaly detected in case '331'.
# Anomaly detected in case '332'.
# Case '333' is compliant.
# Case '334' is compliant.
# Anomaly detected in case '335'.
# Anomaly detected in case '336'.
# Anomaly detected in case '337'.
# Anomaly detected in case '338'.
# Case '339' is compliant.
# Case '340' is compliant.
# Case '341' is compliant.
# Anomaly detected in case '342'.
# Anomaly detected in case '343'.
# Anomaly detected in case '344'.
# Anomaly detected in case '345'.
# Anomaly detected in case '346'.
# Case '347' is compliant.
# Anomaly detected in case '348'.
# Anomaly detected in case '349'.
# Anomaly detected in case '350'.
# Case '351' is compliant.
# Case '352' is compliant.
# Case '353' is compliant.
# Case '354' is compliant.
# Case '355' is compliant.
# Case '356' is compliant.
# Case '357' is compliant.
# Anomaly detected in case '358'.
# Anomaly detected in case '359'.
# Anomaly detected in case '360'.
# Case '361' is compliant.
# Anomaly detected in case '362'.
# Case '363' is compliant.
# Anomaly detected in case '364'.
# Anomaly detected in case '365'.
# Anomaly detected in case '366'.
# Case '367' is compliant.
# Case '368' is compliant.
# Case '369' is compliant.
# Case '370' is compliant.
# Anomaly detected in case '371'.
# Anomaly detected in case '372'.
# Case '373' is compliant.
# Anomaly detected in case '374'.
# Case '375' is compliant.
# Anomaly detected in case '376'.
# Case '377' is compliant.
# Case '378' is compliant.
# Anomaly detected in case '379'.
# Anomaly detected in case '380'.
# Case '381' is compliant.
# Anomaly detected in case '382'.
# Case '383' is compliant.
# Case '384' is compliant.
# Anomaly detected in case '385'.
# Case '386' is compliant.
# Case '387' is compliant.
# Anomaly detected in case '388'.
# Anomaly detected in case '389'.
# Anomaly detected in case '390'.
# Anomaly detected in case '391'.
# Case '392' is compliant.
# Case '393' is compliant.
# Anomaly detected in case '394'.
# Case '395' is compliant.
# Anomaly detected in case '396'.
# Case '397' is compliant.
# Anomaly detected in case '398'.
# Anomaly detected in case '399'.
# Anomaly detected in case '400'.
# Anomaly detected in case '401'.
# Case '402' is compliant.
# Anomaly detected in case '403'.
# Case '404' is compliant.
# Anomaly detected in case '405'.
# Anomaly detected in case '406'.
# Case '407' is compliant.
# Case '408' is compliant.
# Anomaly detected in case '409'.
# Anomaly detected in case '410'.
# Anomaly detected in case '411'.
# Case '412' is compliant.
# Case '413' is compliant.
# Case '414' is compliant.
# Case '415' is compliant.
# Case '416' is compliant.
# Anomaly detected in case '417'.
# Case '418' is compliant.
# Case '419' is compliant.
# Anomaly detected in case '420'.
# Anomaly detected in case '421'.
# Anomaly detected in case '422'.
# Case '423' is compliant.
# Case '424' is compliant.
# Case '425' is compliant.
# Anomaly detected in case '426'.
# Case '427' is compliant.
# Case '428' is compliant.
# Case '429' is compliant.
# Anomaly detected in case '430'.
# Anomaly detected in case '431'.
# Case '432' is compliant.
# Anomaly detected in case '433'.
# Case '434' is compliant.
# Case '435' is compliant.
# Anomaly detected in case '436'.
# Anomaly detected in case '437'.
# Case '438' is compliant.
# Case '439' is compliant.
# Anomaly detected in case '440'.
# Anomaly detected in case '441'.
# Anomaly detected in case '442'.
# Anomaly detected in case '443'.
# Case '444' is compliant.
# Anomaly detected in case '445'.
# Anomaly detected in case '446'.
# Case '447' is compliant.
# Case '448' is compliant.
# Case '449' is compliant.
# Case '450' is compliant.
# Anomaly detected in case '451'.
# Case '452' is compliant.
# Anomaly detected in case '453'.
# Anomaly detected in case '454'.
# Case '455' is compliant.
# Anomaly detected in case '456'.
# Anomaly detected in case '457'.
# Case '458' is compliant.
# Anomaly detected in case '459'.
# Case '460' is compliant.
# Case '461' is compliant.
# Anomaly detected in case '462'.
# Case '463' is compliant.
# Anomaly detected in case '464'.
# Case '465' is compliant.
# Anomaly detected in case '466'.
# Case '467' is compliant.
# Case '468' is compliant.
# Case '469' is compliant.
# Anomaly detected in case '470'.
# Anomaly detected in case '471'.
# Case '472' is compliant.
# Case '473' is compliant.
# Case '474' is compliant.
# Anomaly detected in case '475'.
# Anomaly detected in case '476'.
# Case '477' is compliant.
# Case '478' is compliant.
# Case '479' is compliant.
# Anomaly detected in case '480'.
# Anomaly detected in case '481'.
# Anomaly detected in case '482'.
# Case '483' is compliant.
# Case '484' is compliant.
# Anomaly detected in case '485'.
# Case '486' is compliant.
# Case '487' is compliant.
# Anomaly detected in case '488'.
# Case '489' is compliant.
# Anomaly detected in case '490'.
# Anomaly detected in case '491'.
# Case '492' is compliant.
# Case '493' is compliant.
# Case '494' is compliant.
# Anomaly detected in case '495'.
# Anomaly detected in case '496'.
# Case '497' is compliant.
# Case '498' is compliant.
# Anomaly detected in case '499'.
# Anomaly detected in case '500'.
# Anomaly detected in case '501'.
# Anomaly detected in case '502'.
# Anomaly detected in case '503'.
# Case '504' is compliant.
# Case '505' is compliant.
# Anomaly detected in case '506'.
# Case '507' is compliant.
# Anomaly detected in case '508'.
# Anomaly detected in case '509'.
# Anomaly detected in case '510'.
# Case '511' is compliant.
# Anomaly detected in case '512'.
# Anomaly detected in case '513'.
# Case '514' is compliant.
# Case '515' is compliant.
# Anomaly detected in case '516'.
# Case '517' is compliant.
# Case '518' is compliant.
# Anomaly detected in case '519'.
# Anomaly detected in case '520'.
# Anomaly detected in case '521'.
# Case '522' is compliant.
# Anomaly detected in case '523'.
# Case '524' is compliant.
# Case '525' is compliant.
# Anomaly detected in case '526'.
# Anomaly detected in case '527'.
# Case '528' is compliant.
# Anomaly detected in case '529'.
# Case '530' is compliant.
# Anomaly detected in case '531'.
# Anomaly detected in case '532'.
# Anomaly detected in case '533'.
# Anomaly detected in case '534'.
# Case '535' is compliant.
# Anomaly detected in case '536'.
# Anomaly detected in case '537'.
# Case '538' is compliant.
# Case '539' is compliant.
# Anomaly detected in case '540'.
# Anomaly detected in case '541'.
# Case '542' is compliant.
# Anomaly detected in case '543'.
# Anomaly detected in case '544'.
# Case '545' is compliant.
# Anomaly detected in case '546'.
# Anomaly detected in case '547'.
# Anomaly detected in case '548'.
# Case '549' is compliant.
# Anomaly detected in case '550'.
# Anomaly detected in case '551'.
# Anomaly detected in case '552'.
# Anomaly detected in case '553'.
# Anomaly detected in case '554'.
# Anomaly detected in case '555'.
# Case '556' is compliant.
# Anomaly detected in case '557'.
# Case '558' is compliant.
# Anomaly detected in case '559'.
# Anomaly detected in case '560'.
# Anomaly detected in case '561'.
# Case '562' is compliant.
# Anomaly detected in case '563'.
# Anomaly detected in case '564'.
# Anomaly detected in case '565'.
# Anomaly detected in case '566'.
# Case '567' is compliant.
# Case '568' is compliant.
# Anomaly detected in case '569'.
# Case '570' is compliant.
# Anomaly detected in case '571'.
# Anomaly detected in case '572'.
# Anomaly detected in case '573'.
# Anomaly detected in case '574'.
# Anomaly detected in case '575'.
# Anomaly detected in case '576'.
# Anomaly detected in case '577'.
# Case '578' is compliant.
# Anomaly detected in case '579'.
# Anomaly detected in case '580'.
# Case '581' is compliant.
# Anomaly detected in case '582'.
# Anomaly detected in case '583'.
# Case '584' is compliant.
# Case '585' is compliant.
# Case '586' is compliant.
# Case '587' is compliant.
# Case '588' is compliant.
# Case '589' is compliant.
# Case '590' is compliant.
# Case '591' is compliant.
# Anomaly detected in case '592'.
# Anomaly detected in case '593'.
# Case '594' is compliant.
# Anomaly detected in case '595'.
# Anomaly detected in case '596'.
# Case '597' is compliant.
# Case '598' is compliant.
# Anomaly detected in case '599'.
# Anomaly detected in case '600'.
# Case '601' is compliant.
# Anomaly detected in case '602'.
# Case '603' is compliant.
# Anomaly detected in case '604'.
# Anomaly detected in case '605'.
# Anomaly detected in case '606'.
# Case '607' is compliant.
# Anomaly detected in case '608'.
# Anomaly detected in case '609'.
# Case '610' is compliant.
# Anomaly detected in case '611'.
# Anomaly detected in case '612'.
# Anomaly detected in case '613'.
# Case '614' is compliant.
# Anomaly detected in case '615'.
# Anomaly detected in case '616'.
# Case '617' is compliant.
# Anomaly detected in case '618'.
# Case '619' is compliant.
# Anomaly detected in case '620'.
# Case '621' is compliant.
# Anomaly detected in case '622'.
# Case '623' is compliant.
# Anomaly detected in case '624'.
# Anomaly detected in case '625'.
# Case '626' is compliant.
# Anomaly detected in case '627'.
# Case '628' is compliant.
# Case '629' is compliant.
# Case '630' is compliant.
# Anomaly detected in case '631'.
# Anomaly detected in case '632'.
# Anomaly detected in case '633'.
# Case '634' is compliant.
# Case '635' is compliant.
# Anomaly detected in case '636'.
# Case '637' is compliant.
# Case '638' is compliant.
# Case '639' is compliant.
# Anomaly detected in case '640'.
# Anomaly detected in case '641'.
# Anomaly detected in case '642'.
# Anomaly detected in case '643'.
# Anomaly detected in case '644'.
# Case '645' is compliant.
# Case '646' is compliant.
# Case '647' is compliant.
# Case '648' is compliant.
# Anomaly detected in case '649'.
# Case '650' is compliant.
# Case '651' is compliant.
# Anomaly detected in case '652'.
# Case '653' is compliant.
# Anomaly detected in case '654'.
# Anomaly detected in case '655'.
# Case '656' is compliant.
# Anomaly detected in case '657'.
# Case '658' is compliant.
# Anomaly detected in case '659'.
# Case '660' is compliant.
# Anomaly detected in case '661'.
# Case '662' is compliant.
# Anomaly detected in case '663'.
# Case '664' is compliant.
# Anomaly detected in case '665'.
# Anomaly detected in case '666'.
# Case '667' is compliant.
# Case '668' is compliant.
# Case '669' is compliant.
# Anomaly detected in case '670'.
# Anomaly detected in case '671'.
# Case '672' is compliant.
# Anomaly detected in case '673'.
# Case '674' is compliant.
# Anomaly detected in case '675'.
# Case '676' is compliant.
# Anomaly detected in case '677'.
# Anomaly detected in case '678'.
# Case '679' is compliant.
# Anomaly detected in case '680'.
# Case '681' is compliant.
# Anomaly detected in case '682'.
# Case '683' is compliant.
# Anomaly detected in case '684'.
# Anomaly detected in case '685'.
# Anomaly detected in case '686'.
# Case '687' is compliant.
# Anomaly detected in case '688'.
# Anomaly detected in case '689'.
# Case '690' is compliant.
# Anomaly detected in case '691'.
# Case '692' is compliant.
# Case '693' is compliant.
# Anomaly detected in case '694'.
# Case '695' is compliant.
# Case '696' is compliant.
# Anomaly detected in case '697'.
# Anomaly detected in case '698'.
# Anomaly detected in case '699'.
# Case '700' is compliant.
# Anomaly detected in case '701'.
# Anomaly detected in case '702'.
# Anomaly detected in case '703'.
# Anomaly detected in case '704'.
# Case '705' is compliant.
# Case '706' is compliant.
# Case '707' is compliant.
# Anomaly detected in case '708'.
# Anomaly detected in case '709'.
# Anomaly detected in case '710'.
# Anomaly detected in case '711'.
# Case '712' is compliant.
# Case '713' is compliant.
# Anomaly detected in case '714'.
# Anomaly detected in case '715'.
# Case '716' is compliant.
# Case '717' is compliant.
# Anomaly detected in case '718'.
# Anomaly detected in case '719'.
# Anomaly detected in case '720'.
# Anomaly detected in case '721'.
# Case '722' is compliant.
# Anomaly detected in case '723'.
# Anomaly detected in case '724'.
# Anomaly detected in case '725'.
# Case '726' is compliant.
# Case '727' is compliant.
# Anomaly detected in case '728'.
# Case '729' is compliant.
# Anomaly detected in case '730'.
# Anomaly detected in case '731'.
# Anomaly detected in case '732'.
# Case '733' is compliant.
# Case '734' is compliant.
# Case '735' is compliant.
# Anomaly detected in case '736'.
# Anomaly detected in case '737'.
# Anomaly detected in case '738'.
# Case '739' is compliant.
# Anomaly detected in case '740'.
# Anomaly detected in case '741'.
# Anomaly detected in case '742'.
# Anomaly detected in case '743'.
# Anomaly detected in case '744'.
# Case '745' is compliant.
# Anomaly detected in case '746'.
# Case '747' is compliant.
# Anomaly detected in case '748'.
# Anomaly detected in case '749'.
# Anomaly detected in case '750'.
# Anomaly detected in case '751'.
# Case '752' is compliant.
# Case '753' is compliant.
# Anomaly detected in case '754'.
# Anomaly detected in case '755'.
# Anomaly detected in case '756'.
# Case '757' is compliant.
# Anomaly detected in case '758'.
# Anomaly detected in case '759'.
# Case '760' is compliant.
# Anomaly detected in case '761'.
# Case '762' is compliant.
# Anomaly detected in case '763'.
# Anomaly detected in case '764'.
# Anomaly detected in case '765'.
# Case '766' is compliant.
# Anomaly detected in case '767'.
# Anomaly detected in case '768'.
# Case '769' is compliant.
# Anomaly detected in case '770'.
# Anomaly detected in case '771'.
# Anomaly detected in case '772'.
# Case '773' is compliant.
# Anomaly detected in case '774'.
# Anomaly detected in case '775'.
# Anomaly detected in case '776'.
# Anomaly detected in case '777'.
# Case '778' is compliant.
# Anomaly detected in case '779'.
# Case '780' is compliant.
# Anomaly detected in case '781'.
# Anomaly detected in case '782'.
# Case '783' is compliant.
# Anomaly detected in case '784'.
# Anomaly detected in case '785'.
# Anomaly detected in case '786'.
# Anomaly detected in case '787'.
# Case '788' is compliant.
# Anomaly detected in case '789'.
# Case '790' is compliant.
# Anomaly detected in case '791'.
# Anomaly detected in case '792'.
# Anomaly detected in case '793'.
# Case '794' is compliant.
# Case '795' is compliant.
# Anomaly detected in case '796'.
# Anomaly detected in case '797'.
# Anomaly detected in case '798'.
# Case '799' is compliant.
# Case '800' is compliant.
# Anomaly detected in case '801'.
# Anomaly detected in case '802'.
# Case '803' is compliant.
# Anomaly detected in case '804'.
# Anomaly detected in case '805'.
# Case '806' is compliant.
# Case '807' is compliant.
# Anomaly detected in case '808'.
# Anomaly detected in case '809'.
# Case '810' is compliant.
# Anomaly detected in case '811'.
# Anomaly detected in case '812'.
# Anomaly detected in case '813'.
# Anomaly detected in case '814'.
# Anomaly detected in case '815'.
# Anomaly detected in case '816'.
# Anomaly detected in case '817'.
# Case '818' is compliant.
# Anomaly detected in case '819'.
# Case '820' is compliant.
# Anomaly detected in case '821'.
# Anomaly detected in case '822'.
# Case '823' is compliant.
# Case '824' is compliant.
# Anomaly detected in case '825'.
# Anomaly detected in case '826'.
# Case '827' is compliant.
# Anomaly detected in case '828'.
# Anomaly detected in case '829'.
# Case '830' is compliant.
# Anomaly detected in case '831'.
# Case '832' is compliant.
# Case '833' is compliant.
# Anomaly detected in case '834'.
# Case '835' is compliant.
# Anomaly detected in case '836'.
# Anomaly detected in case '837'.
# Anomaly detected in case '838'.
# Case '839' is compliant.
# Case '840' is compliant.
# Anomaly detected in case '841'.
# Case '842' is compliant.
# Anomaly detected in case '843'.
# Anomaly detected in case '844'.
# Anomaly detected in case '845'.
# Case '846' is compliant.
# Case '847' is compliant.
# Anomaly detected in case '848'.
# Case '849' is compliant.
# Case '850' is compliant.
# Case '851' is compliant.
# Case '852' is compliant.
# Anomaly detected in case '853'.
# Case '854' is compliant.
# Anomaly detected in case '855'.
# Anomaly detected in case '856'.
# Anomaly detected in case '857'.
# Anomaly detected in case '858'.
# Case '859' is compliant.
# Case '860' is compliant.
# Case '861' is compliant.
# Anomaly detected in case '862'.
# Case '863' is compliant.
# Anomaly detected in case '864'.
# Anomaly detected in case '865'.
# Anomaly detected in case '866'.
# Anomaly detected in case '867'.
# Case '868' is compliant.
# Anomaly detected in case '869'.
# Case '870' is compliant.
# Case '871' is compliant.
# Case '872' is compliant.
# Anomaly detected in case '873'.
# Case '874' is compliant.
# Case '875' is compliant.
# Anomaly detected in case '876'.
# Anomaly detected in case '877'.
# Anomaly detected in case '878'.
# Anomaly detected in case '879'.
# Case '880' is compliant.
# Case '881' is compliant.
# Case '882' is compliant.
# Case '883' is compliant.
# Anomaly detected in case '884'.
# Anomaly detected in case '885'.
# Anomaly detected in case '886'.
# Anomaly detected in case '887'.
# Case '888' is compliant.
# Anomaly detected in case '889'.
# Anomaly detected in case '890'.
# Anomaly detected in case '891'.
# Anomaly detected in case '892'.
# Case '893' is compliant.
# Case '894' is compliant.
# Anomaly detected in case '895'.
# Anomaly detected in case '896'.
# Anomaly detected in case '897'.
# Anomaly detected in case '898'.
# Anomaly detected in case '899'.
# Anomaly detected in case '900'.
# Anomaly detected in case '901'.
# Case '902' is compliant.
# Anomaly detected in case '903'.
# Anomaly detected in case '904'.
# Anomaly detected in case '905'.
# Anomaly detected in case '906'.
# Case '907' is compliant.
# Case '908' is compliant.
# Anomaly detected in case '909'.
# Anomaly detected in case '910'.
# Case '911' is compliant.
# Case '912' is compliant.
# Anomaly detected in case '913'.
# Anomaly detected in case '914'.
# Case '915' is compliant.
# Anomaly detected in case '916'.
# Anomaly detected in case '917'.
# Anomaly detected in case '918'.
# Anomaly detected in case '919'.
# Case '920' is compliant.
# Anomaly detected in case '921'.
# Anomaly detected in case '922'.
# Anomaly detected in case '923'.
# Case '924' is compliant.
# Anomaly detected in case '925'.
# Case '926' is compliant.
# Anomaly detected in case '927'.
# Anomaly detected in case '928'.
# Anomaly detected in case '929'.
# Anomaly detected in case '930'.
# Case '931' is compliant.
# Anomaly detected in case '932'.
# Anomaly detected in case '933'.
# Case '934' is compliant.
# Case '935' is compliant.
# Case '936' is compliant.
# Anomaly detected in case '937'.
# Anomaly detected in case '938'.
# Case '939' is compliant.
# Case '940' is compliant.
# Anomaly detected in case '941'.
# Anomaly detected in case '942'.
# Case '943' is compliant.
# Anomaly detected in case '944'.
# Case '945' is compliant.
# Case '946' is compliant.
# Anomaly detected in case '947'.
# Case '948' is compliant.
# Anomaly detected in case '949'.
# Anomaly detected in case '950'.
# Case '951' is compliant.
# Case '952' is compliant.
# Case '953' is compliant.
# Anomaly detected in case '954'.
# Case '955' is compliant.
# Anomaly detected in case '956'.
# Case '957' is compliant.
# Anomaly detected in case '958'.
# Case '959' is compliant.
# Anomaly detected in case '960'.
# Anomaly detected in case '961'.
# Case '962' is compliant.
# Anomaly detected in case '963'.
# Anomaly detected in case '964'.
# Anomaly detected in case '965'.
# Anomaly detected in case '966'.
# Anomaly detected in case '967'.
# Case '968' is compliant.
# Case '969' is compliant.
# Anomaly detected in case '970'.
# Anomaly detected in case '971'.
# Anomaly detected in case '972'.
# Anomaly detected in case '973'.
# Case '974' is compliant.
# Anomaly detected in case '975'.
# Anomaly detected in case '976'.
# Case '977' is compliant.
# Case '978' is compliant.
# Anomaly detected in case '979'.
# Anomaly detected in case '980'.
# Anomaly detected in case '981'.
# Anomaly detected in case '982'.
# Anomaly detected in case '983'.
# Case '984' is compliant.
# Anomaly detected in case '985'.
# Anomaly detected in case '986'.
# Anomaly detected in case '987'.
# Anomaly detected in case '988'.
# Case '989' is compliant.
# Case '990' is compliant.
# Case '991' is compliant.
# Case '992' is compliant.
# Case '993' is compliant.
# Anomaly detected in case '994'.
# Case '995' is compliant.
# Anomaly detected in case '996'.
# Case '997' is compliant.
# Anomaly detected in case '998'.
# Anomaly detected in case '999'.
# Anomaly detected in case '1000'.
# Anomaly detected in case '1001'.
# Anomaly detected in case '1002'.
# Case '1003' is compliant.
# Anomaly detected in case '1004'.
# Case '1005' is compliant.
# Anomaly detected in case '1006'.
# Anomaly detected in case '1007'.
# Anomaly detected in case '1008'.
# Case '1009' is compliant.
# Case '1010' is compliant.
# Case '1011' is compliant.
# Anomaly detected in case '1012'.
# Case '1013' is compliant.
# Case '1014' is compliant.
# Case '1015' is compliant.
# Anomaly detected in case '1016'.
# Anomaly detected in case '1017'.
# Anomaly detected in case '1018'.
# Case '1019' is compliant.
# Case '1020' is compliant.
# Anomaly detected in case '1021'.
# Case '1022' is compliant.
# Case '1023' is compliant.
# Case '1024' is compliant.
# Case '1025' is compliant.
# Case '1026' is compliant.
# Anomaly detected in case '1027'.
# Anomaly detected in case '1028'.
# Case '1029' is compliant.
# Anomaly detected in case '1030'.
# Case '1031' is compliant.
# Anomaly detected in case '1032'.
# Case '1033' is compliant.
# Anomaly detected in case '1034'.
# Anomaly detected in case '1035'.
# Anomaly detected in case '1036'.
# Case '1037' is compliant.
# Anomaly detected in case '1038'.
# Anomaly detected in case '1039'.
# Case '1040' is compliant.
# Case '1041' is compliant.
# Case '1042' is compliant.
# Anomaly detected in case '1043'.
# Anomaly detected in case '1044'.
# Case '1045' is compliant.
# Anomaly detected in case '1046'.
# Case '1047' is compliant.
# Anomaly detected in case '1048'.
# Anomaly detected in case '1049'.
# Case '1050' is compliant.
# Case '1051' is compliant.
# Case '1052' is compliant.
# Case '1053' is compliant.
# Anomaly detected in case '1054'.
# Anomaly detected in case '1055'.
# Anomaly detected in case '1056'.
# Anomaly detected in case '1057'.
# Case '1058' is compliant.
# Anomaly detected in case '1059'.
# Case '1060' is compliant.
# Case '1061' is compliant.
# Anomaly detected in case '1062'.
# Anomaly detected in case '1063'.
# Case '1064' is compliant.
# Case '1065' is compliant.
# Anomaly detected in case '1066'.
# Anomaly detected in case '1067'.
# Anomaly detected in case '1068'.
# Case '1069' is compliant.
# Anomaly detected in case '1070'.
# Case '1071' is compliant.
# Case '1072' is compliant.
# Case '1073' is compliant.
# Anomaly detected in case '1074'.
# Anomaly detected in case '1075'.
# Anomaly detected in case '1076'.
# Case '1077' is compliant.
# Anomaly detected in case '1078'.
# Anomaly detected in case '1079'.
# Anomaly detected in case '1080'.
# Anomaly detected in case '1081'.
# Anomaly detected in case '1082'.
# Case '1083' is compliant.
# Anomaly detected in case '1084'.
# Case '1085' is compliant.
# Case '1086' is compliant.
# Anomaly detected in case '1087'.
# Case '1088' is compliant.
# Anomaly detected in case '1089'.
# Anomaly detected in case '1090'.
# Anomaly detected in case '1091'.
# Anomaly detected in case '1092'.
# Anomaly detected in case '1093'.
# Anomaly detected in case '1094'.
# Case '1095' is compliant.
# Anomaly detected in case '1096'.
# Case '1097' is compliant.
# Case '1098' is compliant.
# Case '1099' is compliant.
# Anomaly detected in case '1100'.
# Anomaly detected in case '1101'.
# Case '1102' is compliant.
# Anomaly detected in case '1103'.
# Anomaly detected in case '1104'.
# Case '1105' is compliant.
# Case '1106' is compliant.
# Case '1107' is compliant.
# Anomaly detected in case '1108'.
# Anomaly detected in case '1109'.
# Case '1110' is compliant.
# Anomaly detected in case '1111'.
# Case '1112' is compliant.
# Anomaly detected in case '1113'.
# Case '1114' is compliant.
# Anomaly detected in case '1115'.
# Anomaly detected in case '1116'.
# Case '1117' is compliant.
# Anomaly detected in case '1118'.
# Case '1119' is compliant.
# Case '1120' is compliant.
# Anomaly detected in case '1121'.
# Case '1122' is compliant.
# Case '1123' is compliant.
# Anomaly detected in case '1124'.
# Anomaly detected in case '1125'.
# Case '1126' is compliant.
# Case '1127' is compliant.
# Case '1128' is compliant.
# Anomaly detected in case '1129'.
# Case '1130' is compliant.
# Anomaly detected in case '1131'.
# Case '1132' is compliant.
# Case '1133' is compliant.
# Anomaly detected in case '1134'.
# Case '1135' is compliant.
# Anomaly detected in case '1136'.
# Anomaly detected in case '1137'.
# Anomaly detected in case '1138'.
# Anomaly detected in case '1139'.
# Anomaly detected in case '1140'.
# Case '1141' is compliant.
# Case '1142' is compliant.
# Case '1143' is compliant.
# Case '1144' is compliant.
# Case '1145' is compliant.
# Anomaly detected in case '1146'.
# Case '1147' is compliant.
# Anomaly detected in case '1148'.
# Anomaly detected in case '1149'.
# Case '1150' is compliant.
# Anomaly detected in case '1151'.
# Case '1152' is compliant.
# Anomaly detected in case '1153'.
# Case '1154' is compliant.
# Anomaly detected in case '1155'.
# Case '1156' is compliant.
# Case '1157' is compliant.
# Anomaly detected in case '1158'.
# Anomaly detected in case '1159'.
# Anomaly detected in case '1160'.
# Case '1161' is compliant.
# Case '1162' is compliant.
# Case '1163' is compliant.
# Anomaly detected in case '1164'.
# Anomaly detected in case '1165'.
# Anomaly detected in case '1166'.
# Case '1167' is compliant.
# Case '1168' is compliant.
# Case '1169' is compliant.
# Anomaly detected in case '1170'.
# Case '1171' is compliant.
# Case '1172' is compliant.
# Anomaly detected in case '1173'.
# Case '1174' is compliant.
# Anomaly detected in case '1175'.
# Case '1176' is compliant.
# Anomaly detected in case '1177'.
# Case '1178' is compliant.
# Case '1179' is compliant.
# Case '1180' is compliant.
# Case '1181' is compliant.
# Case '1182' is compliant.
# Case '1183' is compliant.
# Case '1184' is compliant.
# Case '1185' is compliant.
# Anomaly detected in case '1186'.
# Case '1187' is compliant.
# Case '1188' is compliant.
# Anomaly detected in case '1189'.
# Case '1190' is compliant.
# Case '1191' is compliant.
# Anomaly detected in case '1192'.
# Case '1193' is compliant.
# Anomaly detected in case '1194'.
# Anomaly detected in case '1195'.
# Case '1196' is compliant.
# Case '1197' is compliant.
# Anomaly detected in case '1198'.
# Case '1199' is compliant.
# Anomaly detected in case '1200'.
# Anomaly detected in case '1201'.
# Case '1202' is compliant.
# Anomaly detected in case '1203'.
# Anomaly detected in case '1204'.
# Anomaly detected in case '1205'.
# Case '1206' is compliant.
# Anomaly detected in case '1207'.
# Anomaly detected in case '1208'.
# Anomaly detected in case '1209'.
# Case '1210' is compliant.
# Case '1211' is compliant.
# Case '1212' is compliant.
# Case '1213' is compliant.
# Case '1214' is compliant.
# Anomaly detected in case '1215'.
# Anomaly detected in case '1216'.
# Case '1217' is compliant.
# Anomaly detected in case '1218'.
# Anomaly detected in case '1219'.
# Anomaly detected in case '1220'.
# Anomaly detected in case '1221'.
# Anomaly detected in case '1222'.
# Case '1223' is compliant.
# Case '1224' is compliant.
# Anomaly detected in case '1225'.
# Case '1226' is compliant.
# Anomaly detected in case '1227'.
# Anomaly detected in case '1228'.
# Anomaly detected in case '1229'.
# Anomaly detected in case '1230'.
# Anomaly detected in case '1231'.
# Anomaly detected in case '1232'.
# Case '1233' is compliant.
# Case '1234' is compliant.
# Case '1235' is compliant.
# Case '1236' is compliant.
# Case '1237' is compliant.
# Anomaly detected in case '1238'.
# Case '1239' is compliant.
# Case '1240' is compliant.
# Case '1241' is compliant.
# Anomaly detected in case '1242'.
# Anomaly detected in case '1243'.
# Case '1244' is compliant.
# Case '1245' is compliant.
# Anomaly detected in case '1246'.
# Anomaly detected in case '1247'.
# Case '1248' is compliant.
# Anomaly detected in case '1249'.
# Case '1250' is compliant.
# Anomaly detected in case '1251'.
# Anomaly detected in case '1252'.
# Case '1253' is compliant.
# Case '1254' is compliant.
# Anomaly detected in case '1255'.
# Case '1256' is compliant.
# Anomaly detected in case '1257'.
# Anomaly detected in case '1258'.
# Anomaly detected in case '1259'.
# Anomaly detected in case '1260'.
# Case '1261' is compliant.
# Anomaly detected in case '1262'.
# Anomaly detected in case '1263'.
# Anomaly detected in case '1264'.
# Anomaly detected in case '1265'.
# Case '1266' is compliant.
# Anomaly detected in case '1267'.
# Case '1268' is compliant.
# Anomaly detected in case '1269'.
# Anomaly detected in case '1270'.
# Anomaly detected in case '1271'.
# Case '1272' is compliant.
# Case '1273' is compliant.
# Case '1274' is compliant.
# Anomaly detected in case '1275'.
# Anomaly detected in case '1276'.
# Case '1277' is compliant.
# Anomaly detected in case '1278'.
# Anomaly detected in case '1279'.
# Case '1280' is compliant.
# Case '1281' is compliant.
# Case '1282' is compliant.
# Anomaly detected in case '1283'.
# Case '1284' is compliant.
# Anomaly detected in case '1285'.
# Case '1286' is compliant.
# Case '1287' is compliant.
# Anomaly detected in case '1288'.
# Case '1289' is compliant.
# Anomaly detected in case '1290'.
# Case '1291' is compliant.
# Anomaly detected in case '1292'.
# Case '1293' is compliant.
# Case '1294' is compliant.
# Case '1295' is compliant.
# Case '1296' is compliant.
# Case '1297' is compliant.
# Anomaly detected in case '1298'.
# Anomaly detected in case '1299'.
# Anomaly detected in case '1300'.
# Case '1301' is compliant.
# Case '1302' is compliant.
# Anomaly detected in case '1303'.
# Case '1304' is compliant.
# Case '1305' is compliant.
# Anomaly detected in case '1306'.
# Anomaly detected in case '1307'.
# Anomaly detected in case '1308'.
# Case '1309' is compliant.
# Case '1310' is compliant.
# Case '1311' is compliant.
# Case '1312' is compliant.
# Case '1313' is compliant.
# Anomaly detected in case '1314'.
# Case '1315' is compliant.
# Anomaly detected in case '1316'.
# Anomaly detected in case '1317'.
# Anomaly detected in case '1318'.
# Case '1319' is compliant.
# Case '1320' is compliant.
# Anomaly detected in case '1321'.
# Case '1322' is compliant.
# Case '1323' is compliant.
# Anomaly detected in case '1324'.
# Anomaly detected in case '1325'.
# Anomaly detected in case '1326'.
# Case '1327' is compliant.
# Case '1328' is compliant.
# Anomaly detected in case '1329'.
# Anomaly detected in case '1330'.
# Case '1331' is compliant.
# Case '1332' is compliant.
# Case '1333' is compliant.
# Anomaly detected in case '1334'.
# Case '1335' is compliant.
# Anomaly detected in case '1336'.
# Anomaly detected in case '1337'.
# Anomaly detected in case '1338'.
# Anomaly detected in case '1339'.
# Anomaly detected in case '1340'.
# Case '1341' is compliant.
# Case '1342' is compliant.
# Anomaly detected in case '1343'.
# Anomaly detected in case '1344'.
# Case '1345' is compliant.
# Anomaly detected in case '1346'.
# Case '1347' is compliant.
# Case '1348' is compliant.
# Anomaly detected in case '1349'.
# Anomaly detected in case '1350'.
# Case '1351' is compliant.
# Case '1352' is compliant.
# Anomaly detected in case '1353'.
# Anomaly detected in case '1354'.
# Case '1355' is compliant.
# Anomaly detected in case '1356'.
# Anomaly detected in case '1357'.
# Anomaly detected in case '1358'.
# Case '1359' is compliant.
# Case '1360' is compliant.
# Case '1361' is compliant.
# Anomaly detected in case '1362'.
# Anomaly detected in case '1363'.
# Anomaly detected in case '1364'.
# Case '1365' is compliant.
# Case '1366' is compliant.
# Anomaly detected in case '1367'.
# Anomaly detected in case '1368'.
# Anomaly detected in case '1369'.
# Case '1370' is compliant.
# Case '1371' is compliant.
# Anomaly detected in case '1372'.
# Anomaly detected in case '1373'.
# Anomaly detected in case '1374'.
# Anomaly detected in case '1375'.
# Case '1376' is compliant.
# Case '1377' is compliant.
# Case '1378' is compliant.
# Anomaly detected in case '1379'.
# Anomaly detected in case '1380'.
# Anomaly detected in case '1381'.
# Case '1382' is compliant.
# Anomaly detected in case '1383'.
# Anomaly detected in case '1384'.
# Anomaly detected in case '1385'.
# Anomaly detected in case '1386'.
# Anomaly detected in case '1387'.
# Case '1388' is compliant.
# Anomaly detected in case '1389'.
# Case '1390' is compliant.
# Case '1391' is compliant.
# Anomaly detected in case '1392'.
# Anomaly detected in case '1393'.
# Case '1394' is compliant.
# Case '1395' is compliant.
# Case '1396' is compliant.
# Case '1397' is compliant.
# Anomaly detected in case '1398'.
# Case '1399' is compliant.
# Case '1400' is compliant.
# Case '1401' is compliant.
# Anomaly detected in case '1402'.
# Anomaly detected in case '1403'.
# Anomaly detected in case '1404'.
# Case '1405' is compliant.
# Anomaly detected in case '1406'.
# Anomaly detected in case '1407'.
# Anomaly detected in case '1408'.
# Anomaly detected in case '1409'.
# Anomaly detected in case '1410'.
# Anomaly detected in case '1411'.
# Anomaly detected in case '1412'.
# Case '1413' is compliant.
# Case '1414' is compliant.
# Case '1415' is compliant.
# Anomaly detected in case '1416'.
# Case '1417' is compliant.
# Anomaly detected in case '1418'.
# Anomaly detected in case '1419'.
# Case '1420' is compliant.
# Case '1421' is compliant.
# Anomaly detected in case '1422'.
# Anomaly detected in case '1423'.
# Case '1424' is compliant.
# Case '1425' is compliant.
# Anomaly detected in case '1426'.
# Anomaly detected in case '1427'.
# Anomaly detected in case '1428'.
# Anomaly detected in case '1429'.
# Case '1430' is compliant.
# Anomaly detected in case '1431'.
# Case '1432' is compliant.
# Anomaly detected in case '1433'.
# Anomaly detected in case '1434'.
# Case '1435' is compliant.
# Case '1436' is compliant.
# Case '1437' is compliant.
# Anomaly detected in case '1438'.
# Case '1439' is compliant.
# Case '1440' is compliant.
# Case '1441' is compliant.
# Anomaly detected in case '1442'.
# Case '1443' is compliant.
# Case '1444' is compliant.
# Case '1445' is compliant.
# Anomaly detected in case '1446'.
# Case '1447' is compliant.
# Case '1448' is compliant.
# Case '1449' is compliant.
# Case '1450' is compliant.
# Anomaly detected in case '1451'.
# Anomaly detected in case '1452'.
# Anomaly detected in case '1453'.
# Case '1454' is compliant.
# Anomaly detected in case '1455'.
# Case '1456' is compliant.
# Case '1457' is compliant.
# Case '1458' is compliant.
# Anomaly detected in case '1459'.
# Case '1460' is compliant.
# Case '1461' is compliant.
# Case '1462' is compliant.
# Anomaly detected in case '1463'.
# Anomaly detected in case '1464'.
# Anomaly detected in case '1465'.
# Case '1466' is compliant.
# Case '1467' is compliant.
# Anomaly detected in case '1468'.
# Case '1469' is compliant.
# Anomaly detected in case '1470'.
# Anomaly detected in case '1471'.
# Case '1472' is compliant.
# Anomaly detected in case '1473'.
# Case '1474' is compliant.
# Case '1475' is compliant.
# Anomaly detected in case '1476'.
# Anomaly detected in case '1477'.
# Case '1478' is compliant.
# Case '1479' is compliant.
# Anomaly detected in case '1480'.
# Anomaly detected in case '1481'.
# Case '1482' is compliant.
# Case '1483' is compliant.
# Anomaly detected in case '1484'.
# Case '1485' is compliant.
# Anomaly detected in case '1486'.
# Case '1487' is compliant.
# Anomaly detected in case '1488'.
# Anomaly detected in case '1489'.
# Anomaly detected in case '1490'.
# Case '1491' is compliant.
# Anomaly detected in case '1492'.
# Case '1493' is compliant.
# Case '1494' is compliant.
# Anomaly detected in case '1495'.
# Case '1496' is compliant.
# Case '1497' is compliant.
# Case '1498' is compliant.
# Anomaly detected in case '1499'.
# Case '1500' is compliant.
# Case '1501' is compliant.
# Anomaly detected in case '1502'.
# Anomaly detected in case '1503'.
# Case '1504' is compliant.
# Anomaly detected in case '1505'.
# Anomaly detected in case '1506'.
# Anomaly detected in case '1507'.
# Anomaly detected in case '1508'.
# Case '1509' is compliant.
# Anomaly detected in case '1510'.
# Case '1511' is compliant.
# Anomaly detected in case '1512'.
# Anomaly detected in case '1513'.
# Case '1514' is compliant.
# Anomaly detected in case '1515'.
# Anomaly detected in case '1516'.
# Anomaly detected in case '1517'.
# Anomaly detected in case '1518'.
# Anomaly detected in case '1519'.
# Case '1520' is compliant.
# Anomaly detected in case '1521'.
# Anomaly detected in case '1522'.
# Case '1523' is compliant.
# Anomaly detected in case '1524'.
# Case '1525' is compliant.
# Case '1526' is compliant.
# Case '1527' is compliant.
# Anomaly detected in case '1528'.
# Anomaly detected in case '1529'.
# Anomaly detected in case '1530'.
# Anomaly detected in case '1531'.
# Anomaly detected in case '1532'.
# Case '1533' is compliant.
# Case '1534' is compliant.
# Anomaly detected in case '1535'.
# Anomaly detected in case '1536'.
# Anomaly detected in case '1537'.
# Anomaly detected in case '1538'.
# Anomaly detected in case '1539'.
# Anomaly detected in case '1540'.
# Case '1541' is compliant.
# Case '1542' is compliant.
# Anomaly detected in case '1543'.
# Case '1544' is compliant.
# Case '1545' is compliant.
# Case '1546' is compliant.
# Anomaly detected in case '1547'.
# Case '1548' is compliant.
# Case '1549' is compliant.
# Anomaly detected in case '1550'.
# Case '1551' is compliant.
# Case '1552' is compliant.
# Case '1553' is compliant.
# Anomaly detected in case '1554'.
# Case '1555' is compliant.
# Anomaly detected in case '1556'.
# Case '1557' is compliant.
# Case '1558' is compliant.
# Case '1559' is compliant.
# Case '1560' is compliant.
# Anomaly detected in case '1561'.
# Case '1562' is compliant.
# Anomaly detected in case '1563'.
# Anomaly detected in case '1564'.
# Case '1565' is compliant.
# Anomaly detected in case '1566'.
# Case '1567' is compliant.
# Case '1568' is compliant.
# Case '1569' is compliant.
# Anomaly detected in case '1570'.
# Anomaly detected in case '1571'.
# Case '1572' is compliant.
# Anomaly detected in case '1573'.
# Anomaly detected in case '1574'.
# Case '1575' is compliant.
# Case '1576' is compliant.
# Case '1577' is compliant.
# Anomaly detected in case '1578'.
# Anomaly detected in case '1579'.
# Case '1580' is compliant.
# Anomaly detected in case '1581'.
# Anomaly detected in case '1582'.
# Anomaly detected in case '1583'.
# Anomaly detected in case '1584'.
# Anomaly detected in case '1585'.
# Case '1586' is compliant.
# Case '1587' is compliant.
# Anomaly detected in case '1588'.
# Case '1589' is compliant.
# Anomaly detected in case '1590'.
# Anomaly detected in case '1591'.
# Case '1592' is compliant.
# Case '1593' is compliant.
# Case '1594' is compliant.
# Anomaly detected in case '1595'.
# Case '1596' is compliant.
# Case '1597' is compliant.
# Case '1598' is compliant.
# Case '1599' is compliant.
# Anomaly detected in case '1600'.
# Anomaly detected in case '1601'.
# Case '1602' is compliant.
# Anomaly detected in case '1603'.
# Anomaly detected in case '1604'.
# Anomaly detected in case '1605'.
# Case '1606' is compliant.
# Anomaly detected in case '1607'.
# Case '1608' is compliant.
# Anomaly detected in case '1609'.
# Anomaly detected in case '1610'.
# Case '1611' is compliant.
# Case '1612' is compliant.
# Anomaly detected in case '1613'.
# Anomaly detected in case '1614'.
# Anomaly detected in case '1615'.
# Anomaly detected in case '1616'.
# Anomaly detected in case '1617'.
# Anomaly detected in case '1618'.
# Anomaly detected in case '1619'.
# Case '1620' is compliant.
# Case '1621' is compliant.
# Anomaly detected in case '1622'.
# Anomaly detected in case '1623'.
# Anomaly detected in case '1624'.
# Case '1625' is compliant.
# Anomaly detected in case '1626'.
# Case '1627' is compliant.
# Case '1628' is compliant.
# Case '1629' is compliant.
# Case '1630' is compliant.
# Case '1631' is compliant.
# Anomaly detected in case '1632'.
# Case '1633' is compliant.
# Anomaly detected in case '1634'.
# Anomaly detected in case '1635'.
# Case '1636' is compliant.
# Anomaly detected in case '1637'.
# Anomaly detected in case '1638'.
# Anomaly detected in case '1639'.
# Case '1640' is compliant.
# Case '1641' is compliant.
# Anomaly detected in case '1642'.
# Anomaly detected in case '1643'.
# Anomaly detected in case '1644'.
# Case '1645' is compliant.
# ...
# Anomaly detected in case '99495'.
# Case '99496' is compliant.
# Anomaly detected in case '99497'.
# Case '99498' is compliant.
# Case '99499' is compliant.
# Anomaly detected in case '99500'.
# Anomaly detected in case '99501'.
# Anomaly detected in case '99502'.
# Anomaly detected in case '99503'.
# Case '99504' is compliant.
# Anomaly detected in case '99505'.
# Anomaly detected in case '99506'.
# Case '99507' is compliant.
# Anomaly detected in case '99508'.
# Anomaly detected in case '99509'.
# Case '99510' is compliant.
# Case '99511' is compliant.
# Case '99512' is compliant.
# Anomaly detected in case '99513'.
# Case '99514' is compliant.
# Case '99515' is compliant.
# Case '99516' is compliant.
# Case '99517' is compliant.
# Anomaly detected in case '99518'.
# Anomaly detected in case '99519'.
# Anomaly detected in case '99520'.
# Case '99521' is compliant.
# Anomaly detected in case '99522'.
# Anomaly detected in case '99523'.
# Anomaly detected in case '99524'.
# Anomaly detected in case '99525'.
# Anomaly detected in case '99526'.
# Case '99527' is compliant.
# Anomaly detected in case '99528'.
# Anomaly detected in case '99529'.
# Case '99530' is compliant.
# Case '99531' is compliant.
# Anomaly detected in case '99532'.
# Anomaly detected in case '99533'.
# Case '99534' is compliant.
# Case '99535' is compliant.
# Case '99536' is compliant.
# Anomaly detected in case '99537'.
# Anomaly detected in case '99538'.
# Case '99539' is compliant.
# Anomaly detected in case '99540'.
# Anomaly detected in case '99541'.
# Case '99542' is compliant.
# Anomaly detected in case '99543'.
# Anomaly detected in case '99544'.
# Anomaly detected in case '99545'.
# Anomaly detected in case '99546'.
# Case '99547' is compliant.
# Case '99548' is compliant.
# Anomaly detected in case '99549'.
# Case '99550' is compliant.
# Anomaly detected in case '99551'.
# Case '99552' is compliant.
# Case '99553' is compliant.
# Anomaly detected in case '99554'.
# Anomaly detected in case '99555'.
# Anomaly detected in case '99556'.
# Anomaly detected in case '99557'.
# Case '99558' is compliant.
# Case '99559' is compliant.
# Case '99560' is compliant.
# Anomaly detected in case '99561'.
# Anomaly detected in case '99562'.
# Anomaly detected in case '99563'.
# Case '99564' is compliant.
# Anomaly detected in case '99565'.
# Case '99566' is compliant.
# Case '99567' is compliant.
# Case '99568' is compliant.
# Case '99569' is compliant.
# Anomaly detected in case '99570'.
# Case '99571' is compliant.
# Anomaly detected in case '99572'.
# Anomaly detected in case '99573'.
# Anomaly detected in case '99574'.
# Case '99575' is compliant.
# Case '99576' is compliant.
# Anomaly detected in case '99577'.
# Anomaly detected in case '99578'.
# Case '99579' is compliant.
# Anomaly detected in case '99580'.
# Case '99581' is compliant.
# Anomaly detected in case '99582'.
# Anomaly detected in case '99583'.
# Anomaly detected in case '99584'.
# Anomaly detected in case '99585'.
# Case '99586' is compliant.
# Anomaly detected in case '99587'.
# Case '99588' is compliant.
# Case '99589' is compliant.
# Anomaly detected in case '99590'.
# Anomaly detected in case '99591'.
# Case '99592' is compliant.
# Anomaly detected in case '99593'.
# Case '99594' is compliant.
# Anomaly detected in case '99595'.
# Anomaly detected in case '99596'.
# Anomaly detected in case '99597'.
# Anomaly detected in case '99598'.
# Case '99599' is compliant.
# Anomaly detected in case '99600'.
# Case '99601' is compliant.
# Case '99602' is compliant.
# Anomaly detected in case '99603'.
# Case '99604' is compliant.
# Case '99605' is compliant.
# Case '99606' is compliant.
# Anomaly detected in case '99607'.
# Case '99608' is compliant.
# Case '99609' is compliant.
# Case '99610' is compliant.
# Anomaly detected in case '99611'.
# Anomaly detected in case '99612'.
# Case '99613' is compliant.
# Case '99614' is compliant.
# Case '99615' is compliant.
# Case '99616' is compliant.
# Anomaly detected in case '99617'.
# Case '99618' is compliant.
# Case '99619' is compliant.
# Case '99620' is compliant.
# Anomaly detected in case '99621'.
# Case '99622' is compliant.
# Anomaly detected in case '99623'.
# Anomaly detected in case '99624'.
# Anomaly detected in case '99625'.
# Anomaly detected in case '99626'.
# Anomaly detected in case '99627'.
# Anomaly detected in case '99628'.
# Anomaly detected in case '99629'.
# Anomaly detected in case '99630'.
# Case '99631' is compliant.
# Anomaly detected in case '99632'.
# Case '99633' is compliant.
# Anomaly detected in case '99634'.
# Anomaly detected in case '99635'.
# Case '99636' is compliant.
# Case '99637' is compliant.
# Anomaly detected in case '99638'.
# Anomaly detected in case '99639'.
# Case '99640' is compliant.
# Anomaly detected in case '99641'.
# Anomaly detected in case '99642'.
# Case '99643' is compliant.
# Anomaly detected in case '99644'.
# Case '99645' is compliant.
# Case '99646' is compliant.
# Case '99647' is compliant.
# Case '99648' is compliant.
# Anomaly detected in case '99649'.
# Anomaly detected in case '99650'.
# Anomaly detected in case '99651'.
# Anomaly detected in case '99652'.
# Anomaly detected in case '99653'.
# Anomaly detected in case '99654'.
# Case '99655' is compliant.
# Case '99656' is compliant.
# Anomaly detected in case '99657'.
# Anomaly detected in case '99658'.
# Anomaly detected in case '99659'.
# Anomaly detected in case '99660'.
# Anomaly detected in case '99661'.
# Case '99662' is compliant.
# Case '99663' is compliant.
# Anomaly detected in case '99664'.
# Anomaly detected in case '99665'.
# Case '99666' is compliant.
# Anomaly detected in case '99667'.
# Anomaly detected in case '99668'.
# Case '99669' is compliant.
# Anomaly detected in case '99670'.
# Anomaly detected in case '99671'.
# Case '99672' is compliant.
# Anomaly detected in case '99673'.
# Case '99674' is compliant.
# Anomaly detected in case '99675'.
# Case '99676' is compliant.
# Case '99677' is compliant.
# Anomaly detected in case '99678'.
# Anomaly detected in case '99679'.
# Anomaly detected in case '99680'.
# Case '99681' is compliant.
# Case '99682' is compliant.
# Case '99683' is compliant.
# Case '99684' is compliant.
# Anomaly detected in case '99685'.
# Anomaly detected in case '99686'.
# Anomaly detected in case '99687'.
# Anomaly detected in case '99688'.
# Anomaly detected in case '99689'.
# Case '99690' is compliant.
# Anomaly detected in case '99691'.
# Anomaly detected in case '99692'.
# Anomaly detected in case '99693'.
# Case '99694' is compliant.
# Anomaly detected in case '99695'.
# Anomaly detected in case '99696'.
# Case '99697' is compliant.
# Anomaly detected in case '99698'.
# Case '99699' is compliant.
# Anomaly detected in case '99700'.
# Anomaly detected in case '99701'.
# Anomaly detected in case '99702'.
# Anomaly detected in case '99703'.
# Anomaly detected in case '99704'.
# Case '99705' is compliant.
# Anomaly detected in case '99706'.
# Anomaly detected in case '99707'.
# Case '99708' is compliant.
# Case '99709' is compliant.
# Anomaly detected in case '99710'.
# Case '99711' is compliant.
# Anomaly detected in case '99712'.
# Anomaly detected in case '99713'.
# Case '99714' is compliant.
# Case '99715' is compliant.
# Anomaly detected in case '99716'.
# Anomaly detected in case '99717'.
# Case '99718' is compliant.
# Case '99719' is compliant.
# Case '99720' is compliant.
# Case '99721' is compliant.
# Anomaly detected in case '99722'.
# Case '99723' is compliant.
# Anomaly detected in case '99724'.
# Case '99725' is compliant.
# Case '99726' is compliant.
# Case '99727' is compliant.
# Case '99728' is compliant.
# Anomaly detected in case '99729'.
# Case '99730' is compliant.
# Anomaly detected in case '99731'.
# Case '99732' is compliant.
# Case '99733' is compliant.
# Case '99734' is compliant.
# Case '99735' is compliant.
# Case '99736' is compliant.
# Case '99737' is compliant.
# Case '99738' is compliant.
# Anomaly detected in case '99739'.
# Anomaly detected in case '99740'.
# Anomaly detected in case '99741'.
# Case '99742' is compliant.
# Case '99743' is compliant.
# Anomaly detected in case '99744'.
# Anomaly detected in case '99745'.
# Case '99746' is compliant.
# Anomaly detected in case '99747'.
# Case '99748' is compliant.
# Anomaly detected in case '99749'.
# Anomaly detected in case '99750'.
# Case '99751' is compliant.
# Case '99752' is compliant.
# Case '99753' is compliant.
# Anomaly detected in case '99754'.
# Anomaly detected in case '99755'.
# Anomaly detected in case '99756'.
# Case '99757' is compliant.
# Anomaly detected in case '99758'.
# Case '99759' is compliant.
# Anomaly detected in case '99760'.
# Anomaly detected in case '99761'.
# Case '99762' is compliant.
# Case '99763' is compliant.
# Case '99764' is compliant.
# Anomaly detected in case '99765'.
# Case '99766' is compliant.
# Anomaly detected in case '99767'.
# Case '99768' is compliant.
# Anomaly detected in case '99769'.
# Case '99770' is compliant.
# Anomaly detected in case '99771'.
# Case '99772' is compliant.
# Case '99773' is compliant.
# Anomaly detected in case '99774'.
# Case '99775' is compliant.
# Anomaly detected in case '99776'.
# Case '99777' is compliant.
# Anomaly detected in case '99778'.
# Case '99779' is compliant.
# Anomaly detected in case '99780'.
# Case '99781' is compliant.
# Anomaly detected in case '99782'.
# Anomaly detected in case '99783'.
# Anomaly detected in case '99784'.
# Anomaly detected in case '99785'.
# Anomaly detected in case '99786'.
# Anomaly detected in case '99787'.
# Anomaly detected in case '99788'.
# Anomaly detected in case '99789'.
# Anomaly detected in case '99790'.
# Anomaly detected in case '99791'.
# Case '99792' is compliant.
# Case '99793' is compliant.
# Anomaly detected in case '99794'.
# Case '99795' is compliant.
# Anomaly detected in case '99796'.
# Case '99797' is compliant.
# Case '99798' is compliant.
# Anomaly detected in case '99799'.
# Case '99800' is compliant.
# Anomaly detected in case '99801'.
# Case '99802' is compliant.
# Anomaly detected in case '99803'.
# Anomaly detected in case '99804'.
# Anomaly detected in case '99805'.
# Anomaly detected in case '99806'.
# Anomaly detected in case '99807'.
# Anomaly detected in case '99808'.
# Case '99809' is compliant.
# Case '99810' is compliant.
# Anomaly detected in case '99811'.
# Case '99812' is compliant.
# Anomaly detected in case '99813'.
# Case '99814' is compliant.
# Anomaly detected in case '99815'.
# Case '99816' is compliant.
# Case '99817' is compliant.
# Anomaly detected in case '99818'.
# Case '99819' is compliant.
# Case '99820' is compliant.
# Anomaly detected in case '99821'.
# Anomaly detected in case '99822'.
# Anomaly detected in case '99823'.
# Anomaly detected in case '99824'.
# Anomaly detected in case '99825'.
# Anomaly detected in case '99826'.
# Anomaly detected in case '99827'.
# Case '99828' is compliant.
# Case '99829' is compliant.
# Case '99830' is compliant.
# Anomaly detected in case '99831'.
# Anomaly detected in case '99832'.
# Anomaly detected in case '99833'.
# Anomaly detected in case '99834'.
# Anomaly detected in case '99835'.
# Case '99836' is compliant.
# Anomaly detected in case '99837'.
# Anomaly detected in case '99838'.
# Case '99839' is compliant.
# Case '99840' is compliant.
# Case '99841' is compliant.
# Anomaly detected in case '99842'.
# Case '99843' is compliant.
# Anomaly detected in case '99844'.
# Anomaly detected in case '99845'.
# Anomaly detected in case '99846'.
# Case '99847' is compliant.
# Anomaly detected in case '99848'.
# Anomaly detected in case '99849'.
# Anomaly detected in case '99850'.
# Anomaly detected in case '99851'.
# Case '99852' is compliant.
# Case '99853' is compliant.
# Case '99854' is compliant.
# Anomaly detected in case '99855'.
# Case '99856' is compliant.
# Anomaly detected in case '99857'.
# Anomaly detected in case '99858'.
# Anomaly detected in case '99859'.
# Case '99860' is compliant.
# Anomaly detected in case '99861'.
# Case '99862' is compliant.
# Case '99863' is compliant.
# Anomaly detected in case '99864'.
# Anomaly detected in case '99865'.
# Anomaly detected in case '99866'.
# Case '99867' is compliant.
# Case '99868' is compliant.
# Anomaly detected in case '99869'.
# Anomaly detected in case '99870'.
# Anomaly detected in case '99871'.
# Anomaly detected in case '99872'.
# Anomaly detected in case '99873'.
# Anomaly detected in case '99874'.
# Case '99875' is compliant.
# Anomaly detected in case '99876'.
# Case '99877' is compliant.
# Case '99878' is compliant.
# Anomaly detected in case '99879'.
# Case '99880' is compliant.
# Anomaly detected in case '99881'.
# Anomaly detected in case '99882'.
# Case '99883' is compliant.
# Case '99884' is compliant.
# Anomaly detected in case '99885'.
# Case '99886' is compliant.
# Anomaly detected in case '99887'.
# Case '99888' is compliant.
# Anomaly detected in case '99889'.
# Case '99890' is compliant.
# Anomaly detected in case '99891'.
# Case '99892' is compliant.
# Case '99893' is compliant.
# Case '99894' is compliant.
# Anomaly detected in case '99895'.
# Case '99896' is compliant.
# Case '99897' is compliant.
# Anomaly detected in case '99898'.
# Anomaly detected in case '99899'.
# Case '99900' is compliant.
# Case '99901' is compliant.
# Anomaly detected in case '99902'.
# Anomaly detected in case '99903'.
# Anomaly detected in case '99904'.
# Anomaly detected in case '99905'.
# Case '99906' is compliant.
# Anomaly detected in case '99907'.
# Anomaly detected in case '99908'.
# Case '99909' is compliant.
# Anomaly detected in case '99910'.
# Anomaly detected in case '99911'.
# Case '99912' is compliant.
# Anomaly detected in case '99913'.
# Case '99914' is compliant.
# Case '99915' is compliant.
# Case '99916' is compliant.
# Case '99917' is compliant.
# Anomaly detected in case '99918'.
# Anomaly detected in case '99919'.
# Case '99920' is compliant.
# Anomaly detected in case '99921'.
# Case '99922' is compliant.
# Anomaly detected in case '99923'.
# Anomaly detected in case '99924'.
# Anomaly detected in case '99925'.
# Case '99926' is compliant.
# Case '99927' is compliant.
# Anomaly detected in case '99928'.
# Case '99929' is compliant.
# Case '99930' is compliant.
# Anomaly detected in case '99931'.
# Anomaly detected in case '99932'.
# Case '99933' is compliant.
# Anomaly detected in case '99934'.
# Case '99935' is compliant.
# Anomaly detected in case '99936'.
# Anomaly detected in case '99937'.
# Case '99938' is compliant.
# Case '99939' is compliant.
# Case '99940' is compliant.
# Case '99941' is compliant.
# Case '99942' is compliant.
# Anomaly detected in case '99943'.
# Anomaly detected in case '99944'.
# Anomaly detected in case '99945'.
# Anomaly detected in case '99946'.
# Case '99947' is compliant.
# Case '99948' is compliant.
# Anomaly detected in case '99949'.
# Anomaly detected in case '99950'.
# Case '99951' is compliant.
# Case '99952' is compliant.
# Case '99953' is compliant.
# Case '99954' is compliant.
# Case '99955' is compliant.
# Anomaly detected in case '99956'.
# Anomaly detected in case '99957'.
# Case '99958' is compliant.
# Anomaly detected in case '99959'.
# Anomaly detected in case '99960'.
# Case '99961' is compliant.
# Anomaly detected in case '99962'.
# Case '99963' is compliant.
# Case '99964' is compliant.
# Case '99965' is compliant.
# Anomaly detected in case '99966'.
# Case '99967' is compliant.
# Anomaly detected in case '99968'.
# Anomaly detected in case '99969'.
# Case '99970' is compliant.
# Anomaly detected in case '99971'.
# Case '99972' is compliant.
# Case '99973' is compliant.
# Case '99974' is compliant.
# Case '99975' is compliant.
# Case '99976' is compliant.
# Case '99977' is compliant.
# Case '99978' is compliant.
# Case '99979' is compliant.
# Case '99980' is compliant.
# Anomaly detected in case '99981'.
# Anomaly detected in case '99982'.
# Anomaly detected in case '99983'.
# Anomaly detected in case '99984'.
# Case '99985' is compliant.
# Case '99986' is compliant.
# Case '99987' is compliant.
# Anomaly detected in case '99988'.
# Anomaly detected in case '99989'.
# Anomaly detected in case '99990'.
# Anomaly detected in case '99991'.
# Anomaly detected in case '99992'.
# Case '99993' is compliant.
# Case '99994' is compliant.
# Case '99995' is compliant.
# Anomaly detected in case '99996'.
# Anomaly detected in case '99997'.
# Anomaly detected in case '99998'.
# Anomaly detected in case '99999'.
# Case '100000' is compliant.
# Total cases: 100000
# Compliant cases: 47127 (47.13%)
# Non-compliant cases: 52873 (52.87%)
# Summary saved to data/heuristic_SP_DF_cleaned_SP_DF_cleaned_summary.json
# Compliant cases saved to heuristic_SP_DF_cleaned_SP_DF_cleaned_compliant.csv
# Non-compliant cases saved to heuristic_SP_DF_cleaned_SP_DF_cleaned_non_compliant.csv
# Petri Net model saved as PNG at: heuristic_SP_DF_cleaned_SP_DF_cleaned.png

# %%
pnml_file_path = "./data/alpha_SP_DF_cleaned.pnml"  
log_csv_file_path = "./data/SP_DF_cleaned.csv"  

process_log(pnml_file_path, log_csv_file_path)
# Out:
# replaying log with TBR, completed traces :: 100%|██████████| 1028/1028 [00:02<00:00, 467.12it/s]
# Anomaly detected in case '1'.
# Anomaly detected in case '2'.
# Anomaly detected in case '3'.
# Anomaly detected in case '4'.
# Anomaly detected in case '5'.
# Anomaly detected in case '6'.
# Anomaly detected in case '7'.
# Case '8' is compliant.
# Anomaly detected in case '9'.
# Case '10' is compliant.
# Anomaly detected in case '11'.
# Case '12' is compliant.
# Anomaly detected in case '13'.
# Anomaly detected in case '14'.
# Anomaly detected in case '15'.
# Case '16' is compliant.
# Anomaly detected in case '17'.
# Anomaly detected in case '18'.
# Anomaly detected in case '19'.
# Anomaly detected in case '20'.
# Case '21' is compliant.
# Anomaly detected in case '22'.
# Anomaly detected in case '23'.
# Anomaly detected in case '24'.
# Case '25' is compliant.
# Anomaly detected in case '26'.
# Anomaly detected in case '27'.
# Anomaly detected in case '28'.
# Anomaly detected in case '29'.
# Case '30' is compliant.
# Case '31' is compliant.
# Anomaly detected in case '32'.
# Anomaly detected in case '33'.
# Anomaly detected in case '34'.
# Anomaly detected in case '35'.
# Anomaly detected in case '36'.
# Anomaly detected in case '37'.
# Anomaly detected in case '38'.
# Anomaly detected in case '39'.
# Anomaly detected in case '40'.
# Anomaly detected in case '41'.
# Anomaly detected in case '42'.
# Anomaly detected in case '43'.
# Anomaly detected in case '44'.
# Anomaly detected in case '45'.
# Anomaly detected in case '46'.
# Anomaly detected in case '47'.
# Anomaly detected in case '48'.
# Anomaly detected in case '49'.
# Anomaly detected in case '50'.
# Anomaly detected in case '51'.
# Anomaly detected in case '52'.
# Case '53' is compliant.
# Anomaly detected in case '54'.
# Anomaly detected in case '55'.
# Case '56' is compliant.
# Anomaly detected in case '57'.
# Anomaly detected in case '58'.
# Case '59' is compliant.
# Anomaly detected in case '60'.
# Case '61' is compliant.
# Anomaly detected in case '62'.
# Case '63' is compliant.
# Case '64' is compliant.
# Anomaly detected in case '65'.
# Anomaly detected in case '66'.
# Anomaly detected in case '67'.
# Anomaly detected in case '68'.
# Anomaly detected in case '69'.
# Case '70' is compliant.
# Case '71' is compliant.
# Case '72' is compliant.
# Anomaly detected in case '73'.
# Anomaly detected in case '74'.
# Case '75' is compliant.
# Anomaly detected in case '76'.
# Anomaly detected in case '77'.
# Anomaly detected in case '78'.
# Anomaly detected in case '79'.
# Case '80' is compliant.
# Case '81' is compliant.
# Case '82' is compliant.
# Case '83' is compliant.
# Anomaly detected in case '84'.
# Anomaly detected in case '85'.
# Anomaly detected in case '86'.
# Anomaly detected in case '87'.
# Case '88' is compliant.
# Anomaly detected in case '89'.
# Anomaly detected in case '90'.
# Anomaly detected in case '91'.
# Anomaly detected in case '92'.
# Anomaly detected in case '93'.
# Anomaly detected in case '94'.
# Anomaly detected in case '95'.
# Anomaly detected in case '96'.
# Anomaly detected in case '97'.
# Anomaly detected in case '98'.
# Anomaly detected in case '99'.
# Anomaly detected in case '100'.
# Case '101' is compliant.
# Anomaly detected in case '102'.
# Anomaly detected in case '103'.
# Anomaly detected in case '104'.
# Anomaly detected in case '105'.
# Anomaly detected in case '106'.
# Anomaly detected in case '107'.
# Anomaly detected in case '108'.
# Anomaly detected in case '109'.
# Anomaly detected in case '110'.
# Anomaly detected in case '111'.
# Anomaly detected in case '112'.
# Anomaly detected in case '113'.
# Anomaly detected in case '114'.
# Anomaly detected in case '115'.
# Anomaly detected in case '116'.
# Anomaly detected in case '117'.
# Anomaly detected in case '118'.
# Case '119' is compliant.
# Anomaly detected in case '120'.
# Anomaly detected in case '121'.
# Anomaly detected in case '122'.
# Anomaly detected in case '123'.
# Anomaly detected in case '124'.
# Anomaly detected in case '125'.
# Anomaly detected in case '126'.
# Anomaly detected in case '127'.
# Anomaly detected in case '128'.
# Anomaly detected in case '129'.
# Anomaly detected in case '130'.
# Anomaly detected in case '131'.
# Anomaly detected in case '132'.
# Case '133' is compliant.
# Anomaly detected in case '134'.
# Anomaly detected in case '135'.
# Case '136' is compliant.
# Anomaly detected in case '137'.
# Anomaly detected in case '138'.
# Case '139' is compliant.
# Anomaly detected in case '140'.
# Anomaly detected in case '141'.
# Anomaly detected in case '142'.
# Case '143' is compliant.
# Anomaly detected in case '144'.
# Anomaly detected in case '145'.
# Case '146' is compliant.
# Case '147' is compliant.
# Anomaly detected in case '148'.
# Case '149' is compliant.
# Anomaly detected in case '150'.
# Anomaly detected in case '151'.
# Anomaly detected in case '152'.
# Anomaly detected in case '153'.
# Anomaly detected in case '154'.
# Anomaly detected in case '155'.
# Anomaly detected in case '156'.
# Anomaly detected in case '157'.
# Anomaly detected in case '158'.
# Anomaly detected in case '159'.
# Anomaly detected in case '160'.
# Anomaly detected in case '161'.
# Anomaly detected in case '162'.
# Case '163' is compliant.
# Anomaly detected in case '164'.
# Anomaly detected in case '165'.
# Anomaly detected in case '166'.
# Anomaly detected in case '167'.
# Anomaly detected in case '168'.
# Anomaly detected in case '169'.
# Anomaly detected in case '170'.
# Case '171' is compliant.
# Anomaly detected in case '172'.
# Anomaly detected in case '173'.
# Case '174' is compliant.
# Anomaly detected in case '175'.
# Case '176' is compliant.
# Anomaly detected in case '177'.
# Anomaly detected in case '178'.
# Anomaly detected in case '179'.
# Case '180' is compliant.
# Anomaly detected in case '181'.
# Anomaly detected in case '182'.
# Case '183' is compliant.
# Case '184' is compliant.
# Case '185' is compliant.
# Anomaly detected in case '186'.
# Case '187' is compliant.
# Anomaly detected in case '188'.
# Case '189' is compliant.
# Anomaly detected in case '190'.
# Case '191' is compliant.
# Case '192' is compliant.
# Anomaly detected in case '193'.
# Anomaly detected in case '194'.
# Case '195' is compliant.
# Anomaly detected in case '196'.
# Case '197' is compliant.
# Anomaly detected in case '198'.
# Anomaly detected in case '199'.
# Anomaly detected in case '200'.
# Anomaly detected in case '201'.
# Anomaly detected in case '202'.
# Anomaly detected in case '203'.
# Anomaly detected in case '204'.
# Anomaly detected in case '205'.
# Anomaly detected in case '206'.
# Anomaly detected in case '207'.
# Case '208' is compliant.
# Anomaly detected in case '209'.
# Anomaly detected in case '210'.
# Case '211' is compliant.
# Anomaly detected in case '212'.
# Anomaly detected in case '213'.
# Anomaly detected in case '214'.
# Anomaly detected in case '215'.
# Anomaly detected in case '216'.
# Anomaly detected in case '217'.
# Case '218' is compliant.
# Anomaly detected in case '219'.
# Anomaly detected in case '220'.
# Case '221' is compliant.
# Anomaly detected in case '222'.
# Anomaly detected in case '223'.
# Anomaly detected in case '224'.
# Anomaly detected in case '225'.
# Anomaly detected in case '226'.
# Anomaly detected in case '227'.
# Anomaly detected in case '228'.
# Case '229' is compliant.
# Anomaly detected in case '230'.
# Anomaly detected in case '231'.
# Anomaly detected in case '232'.
# Case '233' is compliant.
# Anomaly detected in case '234'.
# Case '235' is compliant.
# Anomaly detected in case '236'.
# Case '237' is compliant.
# Anomaly detected in case '238'.
# Case '239' is compliant.
# Anomaly detected in case '240'.
# Case '241' is compliant.
# Anomaly detected in case '242'.
# Case '243' is compliant.
# Case '244' is compliant.
# Anomaly detected in case '245'.
# Anomaly detected in case '246'.
# Anomaly detected in case '247'.
# Anomaly detected in case '248'.
# Anomaly detected in case '249'.
# Anomaly detected in case '250'.
# Anomaly detected in case '251'.
# Case '252' is compliant.
# Anomaly detected in case '253'.
# Anomaly detected in case '254'.
# Anomaly detected in case '255'.
# Case '256' is compliant.
# Anomaly detected in case '257'.
# Anomaly detected in case '258'.
# Case '259' is compliant.
# Anomaly detected in case '260'.
# Anomaly detected in case '261'.
# Anomaly detected in case '262'.
# Anomaly detected in case '263'.
# Anomaly detected in case '264'.
# Anomaly detected in case '265'.
# Case '266' is compliant.
# Case '267' is compliant.
# Anomaly detected in case '268'.
# Anomaly detected in case '269'.
# Anomaly detected in case '270'.
# Anomaly detected in case '271'.
# Case '272' is compliant.
# Anomaly detected in case '273'.
# Anomaly detected in case '274'.
# Anomaly detected in case '275'.
# Anomaly detected in case '276'.
# Anomaly detected in case '277'.
# Anomaly detected in case '278'.
# Anomaly detected in case '279'.
# Anomaly detected in case '280'.
# Case '281' is compliant.
# Anomaly detected in case '282'.
# Anomaly detected in case '283'.
# Anomaly detected in case '284'.
# Anomaly detected in case '285'.
# Anomaly detected in case '286'.
# Case '287' is compliant.
# Anomaly detected in case '288'.
# Anomaly detected in case '289'.
# Anomaly detected in case '290'.
# Anomaly detected in case '291'.
# Case '292' is compliant.
# Anomaly detected in case '293'.
# Anomaly detected in case '294'.
# Anomaly detected in case '295'.
# Anomaly detected in case '296'.
# Anomaly detected in case '297'.
# Anomaly detected in case '298'.
# Case '299' is compliant.
# Case '300' is compliant.
# Anomaly detected in case '301'.
# Anomaly detected in case '302'.
# Case '303' is compliant.
# Anomaly detected in case '304'.
# Case '305' is compliant.
# Anomaly detected in case '306'.
# Case '307' is compliant.
# Anomaly detected in case '308'.
# Anomaly detected in case '309'.
# Anomaly detected in case '310'.
# Anomaly detected in case '311'.
# Case '312' is compliant.
# Anomaly detected in case '313'.
# Case '314' is compliant.
# Case '315' is compliant.
# Case '316' is compliant.
# Case '317' is compliant.
# Anomaly detected in case '318'.
# Anomaly detected in case '319'.
# Anomaly detected in case '320'.
# Anomaly detected in case '321'.
# Anomaly detected in case '322'.
# Case '323' is compliant.
# Anomaly detected in case '324'.
# Anomaly detected in case '325'.
# Anomaly detected in case '326'.
# Anomaly detected in case '327'.
# Anomaly detected in case '328'.
# Anomaly detected in case '329'.
# Anomaly detected in case '330'.
# Anomaly detected in case '331'.
# Anomaly detected in case '332'.
# Case '333' is compliant.
# Case '334' is compliant.
# Anomaly detected in case '335'.
# Anomaly detected in case '336'.
# Anomaly detected in case '337'.
# Anomaly detected in case '338'.
# Anomaly detected in case '339'.
# Anomaly detected in case '340'.
# Case '341' is compliant.
# Anomaly detected in case '342'.
# Anomaly detected in case '343'.
# Anomaly detected in case '344'.
# Anomaly detected in case '345'.
# Anomaly detected in case '346'.
# Case '347' is compliant.
# Anomaly detected in case '348'.
# Anomaly detected in case '349'.
# Anomaly detected in case '350'.
# Case '351' is compliant.
# Case '352' is compliant.
# Anomaly detected in case '353'.
# Case '354' is compliant.
# Case '355' is compliant.
# Anomaly detected in case '356'.
# Case '357' is compliant.
# Anomaly detected in case '358'.
# Anomaly detected in case '359'.
# Anomaly detected in case '360'.
# Anomaly detected in case '361'.
# Anomaly detected in case '362'.
# Case '363' is compliant.
# Anomaly detected in case '364'.
# Anomaly detected in case '365'.
# Anomaly detected in case '366'.
# Anomaly detected in case '367'.
# Anomaly detected in case '368'.
# Case '369' is compliant.
# Anomaly detected in case '370'.
# Anomaly detected in case '371'.
# Anomaly detected in case '372'.
# Case '373' is compliant.
# Anomaly detected in case '374'.
# Case '375' is compliant.
# Anomaly detected in case '376'.
# Anomaly detected in case '377'.
# Anomaly detected in case '378'.
# Anomaly detected in case '379'.
# Anomaly detected in case '380'.
# Anomaly detected in case '381'.
# Anomaly detected in case '382'.
# Anomaly detected in case '383'.
# Anomaly detected in case '384'.
# Anomaly detected in case '385'.
# Case '386' is compliant.
# Case '387' is compliant.
# Anomaly detected in case '388'.
# Anomaly detected in case '389'.
# Anomaly detected in case '390'.
# Anomaly detected in case '391'.
# Case '392' is compliant.
# Anomaly detected in case '393'.
# Anomaly detected in case '394'.
# Case '395' is compliant.
# Anomaly detected in case '396'.
# Case '397' is compliant.
# Anomaly detected in case '398'.
# Anomaly detected in case '399'.
# Anomaly detected in case '400'.
# Anomaly detected in case '401'.
# Case '402' is compliant.
# Anomaly detected in case '403'.
# Anomaly detected in case '404'.
# Anomaly detected in case '405'.
# Anomaly detected in case '406'.
# Case '407' is compliant.
# Anomaly detected in case '408'.
# Anomaly detected in case '409'.
# Anomaly detected in case '410'.
# Anomaly detected in case '411'.
# Anomaly detected in case '412'.
# Anomaly detected in case '413'.
# Anomaly detected in case '414'.
# Anomaly detected in case '415'.
# Case '416' is compliant.
# Anomaly detected in case '417'.
# Anomaly detected in case '418'.
# Anomaly detected in case '419'.
# Anomaly detected in case '420'.
# Anomaly detected in case '421'.
# Anomaly detected in case '422'.
# Case '423' is compliant.
# Anomaly detected in case '424'.
# Anomaly detected in case '425'.
# Anomaly detected in case '426'.
# Case '427' is compliant.
# Case '428' is compliant.
# Case '429' is compliant.
# Anomaly detected in case '430'.
# Anomaly detected in case '431'.
# Anomaly detected in case '432'.
# Anomaly detected in case '433'.
# Anomaly detected in case '434'.
# Anomaly detected in case '435'.
# Anomaly detected in case '436'.
# Anomaly detected in case '437'.
# Anomaly detected in case '438'.
# Anomaly detected in case '439'.
# Anomaly detected in case '440'.
# Anomaly detected in case '441'.
# Anomaly detected in case '442'.
# Anomaly detected in case '443'.
# Case '444' is compliant.
# Anomaly detected in case '445'.
# Anomaly detected in case '446'.
# Case '447' is compliant.
# Case '448' is compliant.
# Anomaly detected in case '449'.
# Anomaly detected in case '450'.
# Anomaly detected in case '451'.
# Anomaly detected in case '452'.
# Anomaly detected in case '453'.
# Anomaly detected in case '454'.
# Anomaly detected in case '455'.
# Anomaly detected in case '456'.
# Anomaly detected in case '457'.
# Anomaly detected in case '458'.
# Anomaly detected in case '459'.
# Case '460' is compliant.
# Anomaly detected in case '461'.
# Anomaly detected in case '462'.
# Anomaly detected in case '463'.
# Anomaly detected in case '464'.
# Case '465' is compliant.
# Anomaly detected in case '466'.
# Anomaly detected in case '467'.
# Anomaly detected in case '468'.
# Anomaly detected in case '469'.
# Anomaly detected in case '470'.
# Anomaly detected in case '471'.
# Case '472' is compliant.
# Anomaly detected in case '473'.
# Case '474' is compliant.
# Anomaly detected in case '475'.
# Anomaly detected in case '476'.
# Case '477' is compliant.
# Anomaly detected in case '478'.
# Anomaly detected in case '479'.
# Anomaly detected in case '480'.
# Anomaly detected in case '481'.
# Anomaly detected in case '482'.
# Case '483' is compliant.
# Case '484' is compliant.
# Anomaly detected in case '485'.
# Case '486' is compliant.
# Anomaly detected in case '487'.
# Anomaly detected in case '488'.
# Case '489' is compliant.
# Anomaly detected in case '490'.
# Anomaly detected in case '491'.
# Anomaly detected in case '492'.
# Case '493' is compliant.
# Anomaly detected in case '494'.
# Anomaly detected in case '495'.
# Anomaly detected in case '496'.
# Anomaly detected in case '497'.
# Case '498' is compliant.
# Anomaly detected in case '499'.
# Anomaly detected in case '500'.
# Anomaly detected in case '501'.
# Anomaly detected in case '502'.
# Anomaly detected in case '503'.
# Anomaly detected in case '504'.
# Anomaly detected in case '505'.
# Anomaly detected in case '506'.
# Anomaly detected in case '507'.
# Anomaly detected in case '508'.
# Anomaly detected in case '509'.
# Anomaly detected in case '510'.
# Case '511' is compliant.
# Anomaly detected in case '512'.
# Anomaly detected in case '513'.
# Case '514' is compliant.
# Case '515' is compliant.
# Anomaly detected in case '516'.
# Anomaly detected in case '517'.
# Case '518' is compliant.
# Anomaly detected in case '519'.
# Anomaly detected in case '520'.
# Anomaly detected in case '521'.
# Case '522' is compliant.
# Anomaly detected in case '523'.
# Anomaly detected in case '524'.
# Anomaly detected in case '525'.
# Anomaly detected in case '526'.
# Anomaly detected in case '527'.
# Anomaly detected in case '528'.
# Anomaly detected in case '529'.
# Anomaly detected in case '530'.
# Anomaly detected in case '531'.
# Anomaly detected in case '532'.
# Anomaly detected in case '533'.
# Anomaly detected in case '534'.
# Anomaly detected in case '535'.
# Anomaly detected in case '536'.
# Anomaly detected in case '537'.
# Anomaly detected in case '538'.
# Case '539' is compliant.
# Anomaly detected in case '540'.
# Anomaly detected in case '541'.
# Case '542' is compliant.
# Anomaly detected in case '543'.
# Anomaly detected in case '544'.
# Case '545' is compliant.
# Anomaly detected in case '546'.
# Anomaly detected in case '547'.
# Anomaly detected in case '548'.
# Anomaly detected in case '549'.
# Anomaly detected in case '550'.
# Anomaly detected in case '551'.
# Anomaly detected in case '552'.
# Anomaly detected in case '553'.
# Anomaly detected in case '554'.
# Anomaly detected in case '555'.
# Case '556' is compliant.
# Anomaly detected in case '557'.
# Case '558' is compliant.
# Anomaly detected in case '559'.
# Anomaly detected in case '560'.
# Anomaly detected in case '561'.
# Case '562' is compliant.
# Anomaly detected in case '563'.
# Anomaly detected in case '564'.
# Anomaly detected in case '565'.
# Anomaly detected in case '566'.
# Case '567' is compliant.
# Anomaly detected in case '568'.
# Anomaly detected in case '569'.
# Case '570' is compliant.
# Anomaly detected in case '571'.
# Anomaly detected in case '572'.
# Anomaly detected in case '573'.
# Anomaly detected in case '574'.
# Anomaly detected in case '575'.
# Anomaly detected in case '576'.
# Anomaly detected in case '577'.
# Anomaly detected in case '578'.
# Anomaly detected in case '579'.
# Anomaly detected in case '580'.
# Case '581' is compliant.
# Anomaly detected in case '582'.
# Anomaly detected in case '583'.
# Anomaly detected in case '584'.
# Anomaly detected in case '585'.
# Case '586' is compliant.
# Case '587' is compliant.
# Case '588' is compliant.
# Anomaly detected in case '589'.
# Anomaly detected in case '590'.
# Case '591' is compliant.
# Anomaly detected in case '592'.
# Anomaly detected in case '593'.
# Case '594' is compliant.
# Anomaly detected in case '595'.
# Anomaly detected in case '596'.
# Case '597' is compliant.
# Anomaly detected in case '598'.
# Anomaly detected in case '599'.
# Anomaly detected in case '600'.
# Anomaly detected in case '601'.
# Anomaly detected in case '602'.
# Case '603' is compliant.
# Anomaly detected in case '604'.
# Anomaly detected in case '605'.
# Anomaly detected in case '606'.
# Anomaly detected in case '607'.
# Anomaly detected in case '608'.
# Anomaly detected in case '609'.
# Anomaly detected in case '610'.
# Anomaly detected in case '611'.
# Anomaly detected in case '612'.
# Anomaly detected in case '613'.
# Anomaly detected in case '614'.
# Anomaly detected in case '615'.
# Anomaly detected in case '616'.
# Case '617' is compliant.
# Anomaly detected in case '618'.
# Anomaly detected in case '619'.
# Anomaly detected in case '620'.
# Anomaly detected in case '621'.
# Anomaly detected in case '622'.
# Anomaly detected in case '623'.
# Anomaly detected in case '624'.
# Anomaly detected in case '625'.
# Case '626' is compliant.
# Anomaly detected in case '627'.
# Anomaly detected in case '628'.
# Case '629' is compliant.
# Case '630' is compliant.
# Anomaly detected in case '631'.
# Anomaly detected in case '632'.
# Anomaly detected in case '633'.
# Anomaly detected in case '634'.
# Case '635' is compliant.
# Anomaly detected in case '636'.
# Case '637' is compliant.
# Anomaly detected in case '638'.
# Anomaly detected in case '639'.
# Anomaly detected in case '640'.
# Anomaly detected in case '641'.
# Anomaly detected in case '642'.
# Anomaly detected in case '643'.
# Anomaly detected in case '644'.
# Anomaly detected in case '645'.
# Case '646' is compliant.
# Case '647' is compliant.
# Anomaly detected in case '648'.
# Anomaly detected in case '649'.
# Case '650' is compliant.
# Anomaly detected in case '651'.
# Anomaly detected in case '652'.
# Case '653' is compliant.
# Anomaly detected in case '654'.
# Anomaly detected in case '655'.
# Anomaly detected in case '656'.
# Anomaly detected in case '657'.
# Anomaly detected in case '658'.
# Anomaly detected in case '659'.
# Case '660' is compliant.
# Anomaly detected in case '661'.
# Case '662' is compliant.
# Anomaly detected in case '663'.
# Case '664' is compliant.
# Anomaly detected in case '665'.
# Anomaly detected in case '666'.
# Anomaly detected in case '667'.
# Case '668' is compliant.
# Anomaly detected in case '669'.
# Anomaly detected in case '670'.
# Anomaly detected in case '671'.
# Case '672' is compliant.
# Anomaly detected in case '673'.
# Anomaly detected in case '674'.
# Anomaly detected in case '675'.
# Case '676' is compliant.
# Anomaly detected in case '677'.
# Anomaly detected in case '678'.
# Anomaly detected in case '679'.
# Anomaly detected in case '680'.
# Anomaly detected in case '681'.
# Anomaly detected in case '682'.
# Case '683' is compliant.
# Anomaly detected in case '684'.
# Anomaly detected in case '685'.
# Anomaly detected in case '686'.
# Case '687' is compliant.
# Anomaly detected in case '688'.
# Anomaly detected in case '689'.
# Anomaly detected in case '690'.
# Anomaly detected in case '691'.
# Case '692' is compliant.
# Anomaly detected in case '693'.
# Anomaly detected in case '694'.
# Anomaly detected in case '695'.
# Anomaly detected in case '696'.
# Anomaly detected in case '697'.
# Anomaly detected in case '698'.
# Anomaly detected in case '699'.
# Case '700' is compliant.
# Anomaly detected in case '701'.
# Anomaly detected in case '702'.
# Anomaly detected in case '703'.
# Anomaly detected in case '704'.
# Case '705' is compliant.
# Anomaly detected in case '706'.
# Case '707' is compliant.
# Anomaly detected in case '708'.
# Anomaly detected in case '709'.
# Anomaly detected in case '710'.
# Anomaly detected in case '711'.
# Anomaly detected in case '712'.
# Case '713' is compliant.
# Anomaly detected in case '714'.
# Anomaly detected in case '715'.
# Case '716' is compliant.
# Case '717' is compliant.
# Anomaly detected in case '718'.
# Anomaly detected in case '719'.
# Anomaly detected in case '720'.
# Anomaly detected in case '721'.
# Anomaly detected in case '722'.
# Anomaly detected in case '723'.
# Anomaly detected in case '724'.
# Anomaly detected in case '725'.
# Case '726' is compliant.
# Anomaly detected in case '727'.
# Anomaly detected in case '728'.
# Anomaly detected in case '729'.
# Anomaly detected in case '730'.
# Anomaly detected in case '731'.
# Anomaly detected in case '732'.
# Case '733' is compliant.
# Case '734' is compliant.
# Anomaly detected in case '735'.
# Anomaly detected in case '736'.
# Anomaly detected in case '737'.
# Anomaly detected in case '738'.
# Case '739' is compliant.
# Anomaly detected in case '740'.
# Anomaly detected in case '741'.
# Anomaly detected in case '742'.
# Anomaly detected in case '743'.
# Anomaly detected in case '744'.
# Anomaly detected in case '745'.
# Anomaly detected in case '746'.
# Anomaly detected in case '747'.
# Anomaly detected in case '748'.
# Anomaly detected in case '749'.
# Anomaly detected in case '750'.
# Anomaly detected in case '751'.
# Anomaly detected in case '752'.
# Anomaly detected in case '753'.
# Anomaly detected in case '754'.
# Anomaly detected in case '755'.
# Anomaly detected in case '756'.
# Anomaly detected in case '757'.
# Anomaly detected in case '758'.
# Anomaly detected in case '759'.
# Anomaly detected in case '760'.
# Anomaly detected in case '761'.
# Case '762' is compliant.
# Anomaly detected in case '763'.
# Anomaly detected in case '764'.
# Anomaly detected in case '765'.
# Case '766' is compliant.
# Anomaly detected in case '767'.
# Anomaly detected in case '768'.
# Case '769' is compliant.
# Anomaly detected in case '770'.
# Anomaly detected in case '771'.
# Anomaly detected in case '772'.
# Anomaly detected in case '773'.
# Anomaly detected in case '774'.
# Anomaly detected in case '775'.
# Anomaly detected in case '776'.
# Anomaly detected in case '777'.
# Anomaly detected in case '778'.
# Anomaly detected in case '779'.
# Case '780' is compliant.
# Anomaly detected in case '781'.
# Anomaly detected in case '782'.
# Case '783' is compliant.
# Anomaly detected in case '784'.
# Anomaly detected in case '785'.
# Anomaly detected in case '786'.
# Anomaly detected in case '787'.
# Case '788' is compliant.
# Anomaly detected in case '789'.
# Anomaly detected in case '790'.
# Anomaly detected in case '791'.
# Anomaly detected in case '792'.
# Anomaly detected in case '793'.
# Case '794' is compliant.
# Case '795' is compliant.
# Anomaly detected in case '796'.
# Anomaly detected in case '797'.
# Anomaly detected in case '798'.
# Case '799' is compliant.
# Case '800' is compliant.
# Anomaly detected in case '801'.
# Anomaly detected in case '802'.
# Anomaly detected in case '803'.
# Anomaly detected in case '804'.
# Anomaly detected in case '805'.
# Anomaly detected in case '806'.
# Case '807' is compliant.
# Anomaly detected in case '808'.
# Anomaly detected in case '809'.
# Anomaly detected in case '810'.
# Anomaly detected in case '811'.
# Anomaly detected in case '812'.
# Anomaly detected in case '813'.
# Anomaly detected in case '814'.
# Anomaly detected in case '815'.
# Anomaly detected in case '816'.
# Anomaly detected in case '817'.
# Anomaly detected in case '818'.
# Anomaly detected in case '819'.
# Case '820' is compliant.
# Anomaly detected in case '821'.
# Anomaly detected in case '822'.
# Anomaly detected in case '823'.
# Case '824' is compliant.
# Anomaly detected in case '825'.
# Anomaly detected in case '826'.
# Case '827' is compliant.
# Anomaly detected in case '828'.
# Anomaly detected in case '829'.
# Case '830' is compliant.
# Anomaly detected in case '831'.
# Anomaly detected in case '832'.
# Case '833' is compliant.
# Anomaly detected in case '834'.
# Anomaly detected in case '835'.
# Anomaly detected in case '836'.
# Anomaly detected in case '837'.
# Anomaly detected in case '838'.
# Case '839' is compliant.
# Case '840' is compliant.
# Anomaly detected in case '841'.
# Anomaly detected in case '842'.
# Anomaly detected in case '843'.
# Anomaly detected in case '844'.
# Anomaly detected in case '845'.
# Case '846' is compliant.
# Anomaly detected in case '847'.
# Anomaly detected in case '848'.
# Case '849' is compliant.
# Anomaly detected in case '850'.
# Anomaly detected in case '851'.
# Case '852' is compliant.
# Anomaly detected in case '853'.
# Anomaly detected in case '854'.
# Anomaly detected in case '855'.
# Anomaly detected in case '856'.
# Anomaly detected in case '857'.
# Anomaly detected in case '858'.
# Anomaly detected in case '859'.
# Case '860' is compliant.
# Anomaly detected in case '861'.
# Anomaly detected in case '862'.
# Case '863' is compliant.
# Anomaly detected in case '864'.
# Anomaly detected in case '865'.
# Anomaly detected in case '866'.
# Anomaly detected in case '867'.
# Anomaly detected in case '868'.
# Anomaly detected in case '869'.
# Case '870' is compliant.
# Anomaly detected in case '871'.
# Anomaly detected in case '872'.
# Anomaly detected in case '873'.
# Anomaly detected in case '874'.
# Anomaly detected in case '875'.
# Anomaly detected in case '876'.
# Anomaly detected in case '877'.
# Anomaly detected in case '878'.
# Anomaly detected in case '879'.
# Case '880' is compliant.
# Case '881' is compliant.
# Anomaly detected in case '882'.
# Anomaly detected in case '883'.
# Anomaly detected in case '884'.
# Anomaly detected in case '885'.
# Anomaly detected in case '886'.
# Anomaly detected in case '887'.
# Anomaly detected in case '888'.
# Anomaly detected in case '889'.
# Anomaly detected in case '890'.
# Anomaly detected in case '891'.
# Anomaly detected in case '892'.
# Anomaly detected in case '893'.
# Case '894' is compliant.
# Anomaly detected in case '895'.
# Anomaly detected in case '896'.
# Anomaly detected in case '897'.
# Anomaly detected in case '898'.
# Anomaly detected in case '899'.
# Anomaly detected in case '900'.
# Anomaly detected in case '901'.
# Anomaly detected in case '902'.
# Anomaly detected in case '903'.
# Anomaly detected in case '904'.
# Anomaly detected in case '905'.
# Anomaly detected in case '906'.
# Case '907' is compliant.
# Anomaly detected in case '908'.
# Anomaly detected in case '909'.
# Anomaly detected in case '910'.
# Anomaly detected in case '911'.
# Anomaly detected in case '912'.
# Anomaly detected in case '913'.
# Anomaly detected in case '914'.
# Case '915' is compliant.
# Anomaly detected in case '916'.
# Anomaly detected in case '917'.
# Anomaly detected in case '918'.
# Anomaly detected in case '919'.
# Anomaly detected in case '920'.
# Anomaly detected in case '921'.
# Anomaly detected in case '922'.
# Anomaly detected in case '923'.
# Case '924' is compliant.
# Anomaly detected in case '925'.
# Case '926' is compliant.
# Anomaly detected in case '927'.
# Anomaly detected in case '928'.
# Anomaly detected in case '929'.
# Anomaly detected in case '930'.
# Case '931' is compliant.
# Anomaly detected in case '932'.
# Anomaly detected in case '933'.
# Anomaly detected in case '934'.
# Anomaly detected in case '935'.
# Anomaly detected in case '936'.
# Anomaly detected in case '937'.
# Anomaly detected in case '938'.
# Anomaly detected in case '939'.
# Anomaly detected in case '940'.
# Anomaly detected in case '941'.
# Anomaly detected in case '942'.
# Case '943' is compliant.
# Anomaly detected in case '944'.
# Case '945' is compliant.
# Anomaly detected in case '946'.
# Anomaly detected in case '947'.
# Case '948' is compliant.
# Anomaly detected in case '949'.
# Anomaly detected in case '950'.
# Anomaly detected in case '951'.
# Anomaly detected in case '952'.
# Anomaly detected in case '953'.
# Anomaly detected in case '954'.
# Case '955' is compliant.
# Anomaly detected in case '956'.
# Case '957' is compliant.
# Anomaly detected in case '958'.
# Case '959' is compliant.
# Anomaly detected in case '960'.
# Anomaly detected in case '961'.
# Case '962' is compliant.
# Anomaly detected in case '963'.
# Anomaly detected in case '964'.
# Anomaly detected in case '965'.
# Anomaly detected in case '966'.
# Anomaly detected in case '967'.
# Case '968' is compliant.
# Case '969' is compliant.
# Anomaly detected in case '970'.
# Anomaly detected in case '971'.
# Anomaly detected in case '972'.
# Anomaly detected in case '973'.
# Anomaly detected in case '974'.
# Anomaly detected in case '975'.
# Anomaly detected in case '976'.
# Case '977' is compliant.
# Anomaly detected in case '978'.
# Anomaly detected in case '979'.
# Anomaly detected in case '980'.
# Anomaly detected in case '981'.
# Anomaly detected in case '982'.
# Anomaly detected in case '983'.
# Case '984' is compliant.
# Anomaly detected in case '985'.
# Anomaly detected in case '986'.
# Anomaly detected in case '987'.
# Anomaly detected in case '988'.
# Case '989' is compliant.
# Case '990' is compliant.
# Anomaly detected in case '991'.
# Case '992' is compliant.
# Anomaly detected in case '993'.
# Anomaly detected in case '994'.
# Case '995' is compliant.
# Anomaly detected in case '996'.
# Case '997' is compliant.
# Anomaly detected in case '998'.
# Anomaly detected in case '999'.
# Anomaly detected in case '1000'.
# Anomaly detected in case '1001'.
# Anomaly detected in case '1002'.
# Anomaly detected in case '1003'.
# Anomaly detected in case '1004'.
# Case '1005' is compliant.
# Anomaly detected in case '1006'.
# Anomaly detected in case '1007'.
# Anomaly detected in case '1008'.
# Anomaly detected in case '1009'.
# Anomaly detected in case '1010'.
# Case '1011' is compliant.
# Anomaly detected in case '1012'.
# Case '1013' is compliant.
# Anomaly detected in case '1014'.
# Case '1015' is compliant.
# Anomaly detected in case '1016'.
# Anomaly detected in case '1017'.
# Anomaly detected in case '1018'.
# Anomaly detected in case '1019'.
# Anomaly detected in case '1020'.
# Anomaly detected in case '1021'.
# Anomaly detected in case '1022'.
# Anomaly detected in case '1023'.
# Case '1024' is compliant.
# Anomaly detected in case '1025'.
# Case '1026' is compliant.
# Anomaly detected in case '1027'.
# Anomaly detected in case '1028'.
# Anomaly detected in case '1029'.
# Anomaly detected in case '1030'.
# Anomaly detected in case '1031'.
# Anomaly detected in case '1032'.
# Anomaly detected in case '1033'.
# Anomaly detected in case '1034'.
# Anomaly detected in case '1035'.
# Anomaly detected in case '1036'.
# Case '1037' is compliant.
# Anomaly detected in case '1038'.
# Anomaly detected in case '1039'.
# Case '1040' is compliant.
# Anomaly detected in case '1041'.
# Case '1042' is compliant.
# Anomaly detected in case '1043'.
# Anomaly detected in case '1044'.
# Anomaly detected in case '1045'.
# Anomaly detected in case '1046'.
# Case '1047' is compliant.
# Anomaly detected in case '1048'.
# Anomaly detected in case '1049'.
# Anomaly detected in case '1050'.
# Case '1051' is compliant.
# Case '1052' is compliant.
# Case '1053' is compliant.
# Anomaly detected in case '1054'.
# Anomaly detected in case '1055'.
# Anomaly detected in case '1056'.
# Anomaly detected in case '1057'.
# Case '1058' is compliant.
# Anomaly detected in case '1059'.
# Anomaly detected in case '1060'.
# Anomaly detected in case '1061'.
# Anomaly detected in case '1062'.
# Anomaly detected in case '1063'.
# Case '1064' is compliant.
# Case '1065' is compliant.
# Anomaly detected in case '1066'.
# Anomaly detected in case '1067'.
# Anomaly detected in case '1068'.
# Anomaly detected in case '1069'.
# Anomaly detected in case '1070'.
# Case '1071' is compliant.
# Anomaly detected in case '1072'.
# Anomaly detected in case '1073'.
# Anomaly detected in case '1074'.
# Anomaly detected in case '1075'.
# Anomaly detected in case '1076'.
# Case '1077' is compliant.
# Anomaly detected in case '1078'.
# Anomaly detected in case '1079'.
# Anomaly detected in case '1080'.
# Anomaly detected in case '1081'.
# Anomaly detected in case '1082'.
# Case '1083' is compliant.
# Anomaly detected in case '1084'.
# Case '1085' is compliant.
# Anomaly detected in case '1086'.
# Anomaly detected in case '1087'.
# Case '1088' is compliant.
# Anomaly detected in case '1089'.
# Anomaly detected in case '1090'.
# Anomaly detected in case '1091'.
# Anomaly detected in case '1092'.
# Anomaly detected in case '1093'.
# Anomaly detected in case '1094'.
# Case '1095' is compliant.
# Anomaly detected in case '1096'.
# Case '1097' is compliant.
# Anomaly detected in case '1098'.
# Anomaly detected in case '1099'.
# Anomaly detected in case '1100'.
# Anomaly detected in case '1101'.
# Anomaly detected in case '1102'.
# Anomaly detected in case '1103'.
# Anomaly detected in case '1104'.
# Anomaly detected in case '1105'.
# Case '1106' is compliant.
# Case '1107' is compliant.
# Anomaly detected in case '1108'.
# Anomaly detected in case '1109'.
# Anomaly detected in case '1110'.
# Anomaly detected in case '1111'.
# Anomaly detected in case '1112'.
# Anomaly detected in case '1113'.
# Case '1114' is compliant.
# Anomaly detected in case '1115'.
# Anomaly detected in case '1116'.
# Case '1117' is compliant.
# Anomaly detected in case '1118'.
# Anomaly detected in case '1119'.
# Case '1120' is compliant.
# Anomaly detected in case '1121'.
# Case '1122' is compliant.
# Case '1123' is compliant.
# Anomaly detected in case '1124'.
# Anomaly detected in case '1125'.
# Case '1126' is compliant.
# Anomaly detected in case '1127'.
# Case '1128' is compliant.
# Anomaly detected in case '1129'.
# Anomaly detected in case '1130'.
# Anomaly detected in case '1131'.
# Anomaly detected in case '1132'.
# Anomaly detected in case '1133'.
# Anomaly detected in case '1134'.
# Case '1135' is compliant.
# Anomaly detected in case '1136'.
# Anomaly detected in case '1137'.
# Anomaly detected in case '1138'.
# Anomaly detected in case '1139'.
# Anomaly detected in case '1140'.
# Anomaly detected in case '1141'.
# Anomaly detected in case '1142'.
# Case '1143' is compliant.
# Case '1144' is compliant.
# Anomaly detected in case '1145'.
# Anomaly detected in case '1146'.
# Anomaly detected in case '1147'.
# Anomaly detected in case '1148'.
# Anomaly detected in case '1149'.
# Case '1150' is compliant.
# Anomaly detected in case '1151'.
# Anomaly detected in case '1152'.
# Anomaly detected in case '1153'.
# Anomaly detected in case '1154'.
# Anomaly detected in case '1155'.
# Case '1156' is compliant.
# Anomaly detected in case '1157'.
# Anomaly detected in case '1158'.
# Anomaly detected in case '1159'.
# Anomaly detected in case '1160'.
# Anomaly detected in case '1161'.
# Case '1162' is compliant.
# Case '1163' is compliant.
# Anomaly detected in case '1164'.
# Anomaly detected in case '1165'.
# Anomaly detected in case '1166'.
# Case '1167' is compliant.
# Anomaly detected in case '1168'.
# Case '1169' is compliant.
# Anomaly detected in case '1170'.
# Case '1171' is compliant.
# Anomaly detected in case '1172'.
# Anomaly detected in case '1173'.
# Case '1174' is compliant.
# Anomaly detected in case '1175'.
# Case '1176' is compliant.
# Anomaly detected in case '1177'.
# Anomaly detected in case '1178'.
# Anomaly detected in case '1179'.
# Anomaly detected in case '1180'.
# Anomaly detected in case '1181'.
# Case '1182' is compliant.
# Anomaly detected in case '1183'.
# Case '1184' is compliant.
# Anomaly detected in case '1185'.
# Anomaly detected in case '1186'.
# Anomaly detected in case '1187'.
# Case '1188' is compliant.
# Anomaly detected in case '1189'.
# Anomaly detected in case '1190'.
# Anomaly detected in case '1191'.
# Anomaly detected in case '1192'.
# Anomaly detected in case '1193'.
# Anomaly detected in case '1194'.
# Anomaly detected in case '1195'.
# Case '1196' is compliant.
# Anomaly detected in case '1197'.
# Anomaly detected in case '1198'.
# Anomaly detected in case '1199'.
# Anomaly detected in case '1200'.
# Anomaly detected in case '1201'.
# Anomaly detected in case '1202'.
# Anomaly detected in case '1203'.
# Anomaly detected in case '1204'.
# Anomaly detected in case '1205'.
# Anomaly detected in case '1206'.
# Anomaly detected in case '1207'.
# Anomaly detected in case '1208'.
# Anomaly detected in case '1209'.
# Anomaly detected in case '1210'.
# Case '1211' is compliant.
# Case '1212' is compliant.
# Anomaly detected in case '1213'.
# Anomaly detected in case '1214'.
# Anomaly detected in case '1215'.
# Anomaly detected in case '1216'.
# Anomaly detected in case '1217'.
# Anomaly detected in case '1218'.
# Anomaly detected in case '1219'.
# Anomaly detected in case '1220'.
# Anomaly detected in case '1221'.
# Anomaly detected in case '1222'.
# Anomaly detected in case '1223'.
# Anomaly detected in case '1224'.
# Anomaly detected in case '1225'.
# Anomaly detected in case '1226'.
# Anomaly detected in case '1227'.
# Anomaly detected in case '1228'.
# Anomaly detected in case '1229'.
# Anomaly detected in case '1230'.
# Anomaly detected in case '1231'.
# Anomaly detected in case '1232'.
# Anomaly detected in case '1233'.
# Anomaly detected in case '1234'.
# Case '1235' is compliant.
# Anomaly detected in case '1236'.
# Anomaly detected in case '1237'.
# Anomaly detected in case '1238'.
# Case '1239' is compliant.
# Case '1240' is compliant.
# Anomaly detected in case '1241'.
# Anomaly detected in case '1242'.
# Anomaly detected in case '1243'.
# Anomaly detected in case '1244'.
# Case '1245' is compliant.
# Anomaly detected in case '1246'.
# Anomaly detected in case '1247'.
# Anomaly detected in case '1248'.
# Anomaly detected in case '1249'.
# Anomaly detected in case '1250'.
# Anomaly detected in case '1251'.
# Anomaly detected in case '1252'.
# Anomaly detected in case '1253'.
# Anomaly detected in case '1254'.
# Anomaly detected in case '1255'.
# Anomaly detected in case '1256'.
# Anomaly detected in case '1257'.
# Anomaly detected in case '1258'.
# Anomaly detected in case '1259'.
# Anomaly detected in case '1260'.
# Anomaly detected in case '1261'.
# Anomaly detected in case '1262'.
# Anomaly detected in case '1263'.
# Anomaly detected in case '1264'.
# Anomaly detected in case '1265'.
# Anomaly detected in case '1266'.
# Anomaly detected in case '1267'.
# Anomaly detected in case '1268'.
# Anomaly detected in case '1269'.
# Anomaly detected in case '1270'.
# Anomaly detected in case '1271'.
# Case '1272' is compliant.
# Anomaly detected in case '1273'.
# Anomaly detected in case '1274'.
# Anomaly detected in case '1275'.
# Anomaly detected in case '1276'.
# Case '1277' is compliant.
# Anomaly detected in case '1278'.
# Anomaly detected in case '1279'.
# Case '1280' is compliant.
# Anomaly detected in case '1281'.
# Case '1282' is compliant.
# Anomaly detected in case '1283'.
# Case '1284' is compliant.
# Anomaly detected in case '1285'.
# Case '1286' is compliant.
# Case '1287' is compliant.
# Anomaly detected in case '1288'.
# Anomaly detected in case '1289'.
# Anomaly detected in case '1290'.
# Case '1291' is compliant.
# Anomaly detected in case '1292'.
# Anomaly detected in case '1293'.
# Case '1294' is compliant.
# Case '1295' is compliant.
# Case '1296' is compliant.
# Case '1297' is compliant.
# Anomaly detected in case '1298'.
# Anomaly detected in case '1299'.
# Anomaly detected in case '1300'.
# Anomaly detected in case '1301'.
# Anomaly detected in case '1302'.
# Anomaly detected in case '1303'.
# Anomaly detected in case '1304'.
# Anomaly detected in case '1305'.
# Anomaly detected in case '1306'.
# Anomaly detected in case '1307'.
# Anomaly detected in case '1308'.
# Anomaly detected in case '1309'.
# Case '1310' is compliant.
# Anomaly detected in case '1311'.
# Anomaly detected in case '1312'.
# Anomaly detected in case '1313'.
# Anomaly detected in case '1314'.
# Case '1315' is compliant.
# Anomaly detected in case '1316'.
# Anomaly detected in case '1317'.
# Anomaly detected in case '1318'.
# Case '1319' is compliant.
# Case '1320' is compliant.
# Anomaly detected in case '1321'.
# Anomaly detected in case '1322'.
# Anomaly detected in case '1323'.
# Anomaly detected in case '1324'.
# Anomaly detected in case '1325'.
# Anomaly detected in case '1326'.
# Case '1327' is compliant.
# Case '1328' is compliant.
# Anomaly detected in case '1329'.
# Anomaly detected in case '1330'.
# Case '1331' is compliant.
# Case '1332' is compliant.
# Case '1333' is compliant.
# Anomaly detected in case '1334'.
# Case '1335' is compliant.
# Anomaly detected in case '1336'.
# Anomaly detected in case '1337'.
# Anomaly detected in case '1338'.
# Anomaly detected in case '1339'.
# Anomaly detected in case '1340'.
# Case '1341' is compliant.
# Anomaly detected in case '1342'.
# Anomaly detected in case '1343'.
# Anomaly detected in case '1344'.
# Case '1345' is compliant.
# Anomaly detected in case '1346'.
# Case '1347' is compliant.
# Case '1348' is compliant.
# Anomaly detected in case '1349'.
# Anomaly detected in case '1350'.
# Anomaly detected in case '1351'.
# Case '1352' is compliant.
# Anomaly detected in case '1353'.
# Anomaly detected in case '1354'.
# Case '1355' is compliant.
# Anomaly detected in case '1356'.
# Anomaly detected in case '1357'.
# Anomaly detected in case '1358'.
# Case '1359' is compliant.
# Case '1360' is compliant.
# Case '1361' is compliant.
# Anomaly detected in case '1362'.
# Anomaly detected in case '1363'.
# Anomaly detected in case '1364'.
# Anomaly detected in case '1365'.
# Anomaly detected in case '1366'.
# Anomaly detected in case '1367'.
# Anomaly detected in case '1368'.
# Anomaly detected in case '1369'.
# Case '1370' is compliant.
# Anomaly detected in case '1371'.
# Anomaly detected in case '1372'.
# Anomaly detected in case '1373'.
# Anomaly detected in case '1374'.
# Anomaly detected in case '1375'.
# Case '1376' is compliant.
# Case '1377' is compliant.
# Anomaly detected in case '1378'.
# Anomaly detected in case '1379'.
# Anomaly detected in case '1380'.
# Anomaly detected in case '1381'.
# Anomaly detected in case '1382'.
# Anomaly detected in case '1383'.
# Anomaly detected in case '1384'.
# Anomaly detected in case '1385'.
# Anomaly detected in case '1386'.
# Anomaly detected in case '1387'.
# Anomaly detected in case '1388'.
# Anomaly detected in case '1389'.
# Case '1390' is compliant.
# Case '1391' is compliant.
# Anomaly detected in case '1392'.
# Anomaly detected in case '1393'.
# Anomaly detected in case '1394'.
# Anomaly detected in case '1395'.
# Anomaly detected in case '1396'.
# Anomaly detected in case '1397'.
# Anomaly detected in case '1398'.
# Case '1399' is compliant.
# Anomaly detected in case '1400'.
# Anomaly detected in case '1401'.
# Anomaly detected in case '1402'.
# Anomaly detected in case '1403'.
# Anomaly detected in case '1404'.
# Case '1405' is compliant.
# Anomaly detected in case '1406'.
# Anomaly detected in case '1407'.
# Anomaly detected in case '1408'.
# Anomaly detected in case '1409'.
# Anomaly detected in case '1410'.
# Anomaly detected in case '1411'.
# Anomaly detected in case '1412'.
# Case '1413' is compliant.
# Anomaly detected in case '1414'.
# Case '1415' is compliant.
# Anomaly detected in case '1416'.
# Case '1417' is compliant.
# Anomaly detected in case '1418'.
# Anomaly detected in case '1419'.
# Case '1420' is compliant.
# Anomaly detected in case '1421'.
# Anomaly detected in case '1422'.
# Anomaly detected in case '1423'.
# Anomaly detected in case '1424'.
# Anomaly detected in case '1425'.
# Anomaly detected in case '1426'.
# Anomaly detected in case '1427'.
# Anomaly detected in case '1428'.
# Anomaly detected in case '1429'.
# Case '1430' is compliant.
# Anomaly detected in case '1431'.
# Anomaly detected in case '1432'.
# Anomaly detected in case '1433'.
# Anomaly detected in case '1434'.
# Case '1435' is compliant.
# Anomaly detected in case '1436'.
# Anomaly detected in case '1437'.
# Anomaly detected in case '1438'.
# Anomaly detected in case '1439'.
# Anomaly detected in case '1440'.
# Case '1441' is compliant.
# Anomaly detected in case '1442'.
# Case '1443' is compliant.
# Case '1444' is compliant.
# Anomaly detected in case '1445'.
# Anomaly detected in case '1446'.
# Case '1447' is compliant.
# Anomaly detected in case '1448'.
# Anomaly detected in case '1449'.
# Anomaly detected in case '1450'.
# Anomaly detected in case '1451'.
# Anomaly detected in case '1452'.
# Anomaly detected in case '1453'.
# Anomaly detected in case '1454'.
# Anomaly detected in case '1455'.
# Anomaly detected in case '1456'.
# Case '1457' is compliant.
# Case '1458' is compliant.
# Anomaly detected in case '1459'.
# Case '1460' is compliant.
# Anomaly detected in case '1461'.
# Anomaly detected in case '1462'.
# Anomaly detected in case '1463'.
# Anomaly detected in case '1464'.
# Anomaly detected in case '1465'.
# Case '1466' is compliant.
# Case '1467' is compliant.
# Anomaly detected in case '1468'.
# Anomaly detected in case '1469'.
# Anomaly detected in case '1470'.
# Anomaly detected in case '1471'.
# Case '1472' is compliant.
# Anomaly detected in case '1473'.
# Case '1474' is compliant.
# Anomaly detected in case '1475'.
# Anomaly detected in case '1476'.
# Anomaly detected in case '1477'.
# Anomaly detected in case '1478'.
# Case '1479' is compliant.
# Anomaly detected in case '1480'.
# Anomaly detected in case '1481'.
# Anomaly detected in case '1482'.
# Anomaly detected in case '1483'.
# Anomaly detected in case '1484'.
# Anomaly detected in case '1485'.
# Anomaly detected in case '1486'.
# Case '1487' is compliant.
# Anomaly detected in case '1488'.
# Anomaly detected in case '1489'.
# Anomaly detected in case '1490'.
# Case '1491' is compliant.
# Anomaly detected in case '1492'.
# Case '1493' is compliant.
# Case '1494' is compliant.
# Anomaly detected in case '1495'.
# Case '1496' is compliant.
# Anomaly detected in case '1497'.
# Anomaly detected in case '1498'.
# Anomaly detected in case '1499'.
# Anomaly detected in case '1500'.
# Anomaly detected in case '1501'.
# Anomaly detected in case '1502'.
# Anomaly detected in case '1503'.
# Case '1504' is compliant.
# Anomaly detected in case '1505'.
# Anomaly detected in case '1506'.
# Anomaly detected in case '1507'.
# Anomaly detected in case '1508'.
# Anomaly detected in case '1509'.
# Anomaly detected in case '1510'.
# Case '1511' is compliant.
# Anomaly detected in case '1512'.
# Anomaly detected in case '1513'.
# Case '1514' is compliant.
# Anomaly detected in case '1515'.
# Anomaly detected in case '1516'.
# Anomaly detected in case '1517'.
# Anomaly detected in case '1518'.
# Anomaly detected in case '1519'.
# Anomaly detected in case '1520'.
# Anomaly detected in case '1521'.
# Anomaly detected in case '1522'.
# Case '1523' is compliant.
# Anomaly detected in case '1524'.
# Anomaly detected in case '1525'.
# Anomaly detected in case '1526'.
# Anomaly detected in case '1527'.
# Anomaly detected in case '1528'.
# Anomaly detected in case '1529'.
# Anomaly detected in case '1530'.
# Anomaly detected in case '1531'.
# Anomaly detected in case '1532'.
# Case '1533' is compliant.
# Anomaly detected in case '1534'.
# Anomaly detected in case '1535'.
# Anomaly detected in case '1536'.
# Anomaly detected in case '1537'.
# Anomaly detected in case '1538'.
# Anomaly detected in case '1539'.
# Anomaly detected in case '1540'.
# Anomaly detected in case '1541'.
# Anomaly detected in case '1542'.
# Anomaly detected in case '1543'.
# Anomaly detected in case '1544'.
# Case '1545' is compliant.
# Anomaly detected in case '1546'.
# Anomaly detected in case '1547'.
# Anomaly detected in case '1548'.
# Anomaly detected in case '1549'.
# Anomaly detected in case '1550'.
# Anomaly detected in case '1551'.
# Anomaly detected in case '1552'.
# Case '1553' is compliant.
# Anomaly detected in case '1554'.
# Case '1555' is compliant.
# Anomaly detected in case '1556'.
# ...
# Anomaly detected in case '99520'.
# Case '99521' is compliant.
# Anomaly detected in case '99522'.
# Anomaly detected in case '99523'.
# Anomaly detected in case '99524'.
# Anomaly detected in case '99525'.
# Anomaly detected in case '99526'.
# Case '99527' is compliant.
# Anomaly detected in case '99528'.
# Anomaly detected in case '99529'.
# Anomaly detected in case '99530'.
# Anomaly detected in case '99531'.
# Anomaly detected in case '99532'.
# Anomaly detected in case '99533'.
# Anomaly detected in case '99534'.
# Anomaly detected in case '99535'.
# Case '99536' is compliant.
# Anomaly detected in case '99537'.
# Anomaly detected in case '99538'.
# Anomaly detected in case '99539'.
# Anomaly detected in case '99540'.
# Anomaly detected in case '99541'.
# Case '99542' is compliant.
# Anomaly detected in case '99543'.
# Anomaly detected in case '99544'.
# Anomaly detected in case '99545'.
# Anomaly detected in case '99546'.
# Anomaly detected in case '99547'.
# Anomaly detected in case '99548'.
# Anomaly detected in case '99549'.
# Anomaly detected in case '99550'.
# Anomaly detected in case '99551'.
# Case '99552' is compliant.
# Anomaly detected in case '99553'.
# Anomaly detected in case '99554'.
# Anomaly detected in case '99555'.
# Anomaly detected in case '99556'.
# Anomaly detected in case '99557'.
# Case '99558' is compliant.
# Case '99559' is compliant.
# Anomaly detected in case '99560'.
# Anomaly detected in case '99561'.
# Anomaly detected in case '99562'.
# Anomaly detected in case '99563'.
# Case '99564' is compliant.
# Anomaly detected in case '99565'.
# Case '99566' is compliant.
# Case '99567' is compliant.
# Anomaly detected in case '99568'.
# Case '99569' is compliant.
# Anomaly detected in case '99570'.
# Case '99571' is compliant.
# Anomaly detected in case '99572'.
# Anomaly detected in case '99573'.
# Anomaly detected in case '99574'.
# Case '99575' is compliant.
# Anomaly detected in case '99576'.
# Anomaly detected in case '99577'.
# Anomaly detected in case '99578'.
# Case '99579' is compliant.
# Anomaly detected in case '99580'.
# Case '99581' is compliant.
# Anomaly detected in case '99582'.
# Anomaly detected in case '99583'.
# Anomaly detected in case '99584'.
# Anomaly detected in case '99585'.
# Anomaly detected in case '99586'.
# Anomaly detected in case '99587'.
# Anomaly detected in case '99588'.
# Case '99589' is compliant.
# Anomaly detected in case '99590'.
# Anomaly detected in case '99591'.
# Anomaly detected in case '99592'.
# Anomaly detected in case '99593'.
# Case '99594' is compliant.
# Anomaly detected in case '99595'.
# Anomaly detected in case '99596'.
# Anomaly detected in case '99597'.
# Anomaly detected in case '99598'.
# Anomaly detected in case '99599'.
# Anomaly detected in case '99600'.
# Case '99601' is compliant.
# Anomaly detected in case '99602'.
# Anomaly detected in case '99603'.
# Anomaly detected in case '99604'.
# Anomaly detected in case '99605'.
# Anomaly detected in case '99606'.
# Anomaly detected in case '99607'.
# Anomaly detected in case '99608'.
# Case '99609' is compliant.
# Anomaly detected in case '99610'.
# Anomaly detected in case '99611'.
# Anomaly detected in case '99612'.
# Case '99613' is compliant.
# Case '99614' is compliant.
# Anomaly detected in case '99615'.
# Anomaly detected in case '99616'.
# Anomaly detected in case '99617'.
# Case '99618' is compliant.
# Anomaly detected in case '99619'.
# Anomaly detected in case '99620'.
# Anomaly detected in case '99621'.
# Case '99622' is compliant.
# Anomaly detected in case '99623'.
# Anomaly detected in case '99624'.
# Anomaly detected in case '99625'.
# Anomaly detected in case '99626'.
# Anomaly detected in case '99627'.
# Anomaly detected in case '99628'.
# Anomaly detected in case '99629'.
# Anomaly detected in case '99630'.
# Case '99631' is compliant.
# Anomaly detected in case '99632'.
# Anomaly detected in case '99633'.
# Anomaly detected in case '99634'.
# Anomaly detected in case '99635'.
# Anomaly detected in case '99636'.
# Case '99637' is compliant.
# Anomaly detected in case '99638'.
# Anomaly detected in case '99639'.
# Anomaly detected in case '99640'.
# Anomaly detected in case '99641'.
# Anomaly detected in case '99642'.
# Anomaly detected in case '99643'.
# Anomaly detected in case '99644'.
# Case '99645' is compliant.
# Anomaly detected in case '99646'.
# Anomaly detected in case '99647'.
# Anomaly detected in case '99648'.
# Anomaly detected in case '99649'.
# Anomaly detected in case '99650'.
# Anomaly detected in case '99651'.
# Anomaly detected in case '99652'.
# Anomaly detected in case '99653'.
# Anomaly detected in case '99654'.
# Case '99655' is compliant.
# Anomaly detected in case '99656'.
# Anomaly detected in case '99657'.
# Anomaly detected in case '99658'.
# Anomaly detected in case '99659'.
# Anomaly detected in case '99660'.
# Anomaly detected in case '99661'.
# Anomaly detected in case '99662'.
# Anomaly detected in case '99663'.
# Anomaly detected in case '99664'.
# Anomaly detected in case '99665'.
# Anomaly detected in case '99666'.
# Anomaly detected in case '99667'.
# Anomaly detected in case '99668'.
# Anomaly detected in case '99669'.
# Anomaly detected in case '99670'.
# Anomaly detected in case '99671'.
# Anomaly detected in case '99672'.
# Anomaly detected in case '99673'.
# Anomaly detected in case '99674'.
# Anomaly detected in case '99675'.
# Case '99676' is compliant.
# Anomaly detected in case '99677'.
# Anomaly detected in case '99678'.
# Anomaly detected in case '99679'.
# Anomaly detected in case '99680'.
# Anomaly detected in case '99681'.
# Anomaly detected in case '99682'.
# Anomaly detected in case '99683'.
# Anomaly detected in case '99684'.
# Anomaly detected in case '99685'.
# Anomaly detected in case '99686'.
# Anomaly detected in case '99687'.
# Anomaly detected in case '99688'.
# Anomaly detected in case '99689'.
# Case '99690' is compliant.
# Anomaly detected in case '99691'.
# Anomaly detected in case '99692'.
# Anomaly detected in case '99693'.
# Case '99694' is compliant.
# Anomaly detected in case '99695'.
# Anomaly detected in case '99696'.
# Anomaly detected in case '99697'.
# Anomaly detected in case '99698'.
# Case '99699' is compliant.
# Anomaly detected in case '99700'.
# Anomaly detected in case '99701'.
# Anomaly detected in case '99702'.
# Anomaly detected in case '99703'.
# Anomaly detected in case '99704'.
# Anomaly detected in case '99705'.
# Anomaly detected in case '99706'.
# Anomaly detected in case '99707'.
# Anomaly detected in case '99708'.
# Anomaly detected in case '99709'.
# Anomaly detected in case '99710'.
# Case '99711' is compliant.
# Anomaly detected in case '99712'.
# Anomaly detected in case '99713'.
# Anomaly detected in case '99714'.
# Case '99715' is compliant.
# Anomaly detected in case '99716'.
# Anomaly detected in case '99717'.
# Anomaly detected in case '99718'.
# Anomaly detected in case '99719'.
# Anomaly detected in case '99720'.
# Anomaly detected in case '99721'.
# Anomaly detected in case '99722'.
# Anomaly detected in case '99723'.
# Anomaly detected in case '99724'.
# Anomaly detected in case '99725'.
# Anomaly detected in case '99726'.
# Anomaly detected in case '99727'.
# Case '99728' is compliant.
# Anomaly detected in case '99729'.
# Case '99730' is compliant.
# Anomaly detected in case '99731'.
# Anomaly detected in case '99732'.
# Case '99733' is compliant.
# Case '99734' is compliant.
# Case '99735' is compliant.
# Anomaly detected in case '99736'.
# Anomaly detected in case '99737'.
# Anomaly detected in case '99738'.
# Anomaly detected in case '99739'.
# Anomaly detected in case '99740'.
# Anomaly detected in case '99741'.
# Case '99742' is compliant.
# Case '99743' is compliant.
# Anomaly detected in case '99744'.
# Anomaly detected in case '99745'.
# Case '99746' is compliant.
# Anomaly detected in case '99747'.
# Case '99748' is compliant.
# Anomaly detected in case '99749'.
# Anomaly detected in case '99750'.
# Case '99751' is compliant.
# Case '99752' is compliant.
# Case '99753' is compliant.
# Anomaly detected in case '99754'.
# Anomaly detected in case '99755'.
# Anomaly detected in case '99756'.
# Case '99757' is compliant.
# Anomaly detected in case '99758'.
# Case '99759' is compliant.
# Anomaly detected in case '99760'.
# Anomaly detected in case '99761'.
# Anomaly detected in case '99762'.
# Case '99763' is compliant.
# Case '99764' is compliant.
# Anomaly detected in case '99765'.
# Anomaly detected in case '99766'.
# Anomaly detected in case '99767'.
# Anomaly detected in case '99768'.
# Anomaly detected in case '99769'.
# Case '99770' is compliant.
# Anomaly detected in case '99771'.
# Case '99772' is compliant.
# Anomaly detected in case '99773'.
# Anomaly detected in case '99774'.
# Anomaly detected in case '99775'.
# Anomaly detected in case '99776'.
# Anomaly detected in case '99777'.
# Anomaly detected in case '99778'.
# Anomaly detected in case '99779'.
# Anomaly detected in case '99780'.
# Anomaly detected in case '99781'.
# Anomaly detected in case '99782'.
# Anomaly detected in case '99783'.
# Anomaly detected in case '99784'.
# Anomaly detected in case '99785'.
# Anomaly detected in case '99786'.
# Anomaly detected in case '99787'.
# Anomaly detected in case '99788'.
# Anomaly detected in case '99789'.
# Anomaly detected in case '99790'.
# Anomaly detected in case '99791'.
# Anomaly detected in case '99792'.
# Anomaly detected in case '99793'.
# Anomaly detected in case '99794'.
# Case '99795' is compliant.
# Anomaly detected in case '99796'.
# Anomaly detected in case '99797'.
# Anomaly detected in case '99798'.
# Anomaly detected in case '99799'.
# Case '99800' is compliant.
# Anomaly detected in case '99801'.
# Anomaly detected in case '99802'.
# Anomaly detected in case '99803'.
# Anomaly detected in case '99804'.
# Anomaly detected in case '99805'.
# Anomaly detected in case '99806'.
# Anomaly detected in case '99807'.
# Anomaly detected in case '99808'.
# Case '99809' is compliant.
# Anomaly detected in case '99810'.
# Anomaly detected in case '99811'.
# Case '99812' is compliant.
# Anomaly detected in case '99813'.
# Case '99814' is compliant.
# Anomaly detected in case '99815'.
# Case '99816' is compliant.
# Case '99817' is compliant.
# Anomaly detected in case '99818'.
# Case '99819' is compliant.
# Case '99820' is compliant.
# Anomaly detected in case '99821'.
# Anomaly detected in case '99822'.
# Anomaly detected in case '99823'.
# Anomaly detected in case '99824'.
# Anomaly detected in case '99825'.
# Anomaly detected in case '99826'.
# Anomaly detected in case '99827'.
# Anomaly detected in case '99828'.
# Case '99829' is compliant.
# Anomaly detected in case '99830'.
# Anomaly detected in case '99831'.
# Anomaly detected in case '99832'.
# Anomaly detected in case '99833'.
# Anomaly detected in case '99834'.
# Anomaly detected in case '99835'.
# Anomaly detected in case '99836'.
# Anomaly detected in case '99837'.
# Anomaly detected in case '99838'.
# Case '99839' is compliant.
# Case '99840' is compliant.
# Case '99841' is compliant.
# Anomaly detected in case '99842'.
# Case '99843' is compliant.
# Anomaly detected in case '99844'.
# Anomaly detected in case '99845'.
# Anomaly detected in case '99846'.
# Anomaly detected in case '99847'.
# Anomaly detected in case '99848'.
# Anomaly detected in case '99849'.
# Anomaly detected in case '99850'.
# Anomaly detected in case '99851'.
# Anomaly detected in case '99852'.
# Case '99853' is compliant.
# Case '99854' is compliant.
# Anomaly detected in case '99855'.
# Anomaly detected in case '99856'.
# Anomaly detected in case '99857'.
# Anomaly detected in case '99858'.
# Anomaly detected in case '99859'.
# Case '99860' is compliant.
# Anomaly detected in case '99861'.
# Anomaly detected in case '99862'.
# Anomaly detected in case '99863'.
# Anomaly detected in case '99864'.
# Anomaly detected in case '99865'.
# Anomaly detected in case '99866'.
# Anomaly detected in case '99867'.
# Anomaly detected in case '99868'.
# Anomaly detected in case '99869'.
# Anomaly detected in case '99870'.
# Anomaly detected in case '99871'.
# Anomaly detected in case '99872'.
# Anomaly detected in case '99873'.
# Anomaly detected in case '99874'.
# Anomaly detected in case '99875'.
# Anomaly detected in case '99876'.
# Anomaly detected in case '99877'.
# Anomaly detected in case '99878'.
# Anomaly detected in case '99879'.
# Case '99880' is compliant.
# Anomaly detected in case '99881'.
# Anomaly detected in case '99882'.
# Anomaly detected in case '99883'.
# Anomaly detected in case '99884'.
# Anomaly detected in case '99885'.
# Case '99886' is compliant.
# Anomaly detected in case '99887'.
# Anomaly detected in case '99888'.
# Anomaly detected in case '99889'.
# Anomaly detected in case '99890'.
# Anomaly detected in case '99891'.
# Case '99892' is compliant.
# Case '99893' is compliant.
# Case '99894' is compliant.
# Anomaly detected in case '99895'.
# Anomaly detected in case '99896'.
# Case '99897' is compliant.
# Anomaly detected in case '99898'.
# Anomaly detected in case '99899'.
# Case '99900' is compliant.
# Case '99901' is compliant.
# Anomaly detected in case '99902'.
# Anomaly detected in case '99903'.
# Anomaly detected in case '99904'.
# Anomaly detected in case '99905'.
# Anomaly detected in case '99906'.
# Anomaly detected in case '99907'.
# Anomaly detected in case '99908'.
# Case '99909' is compliant.
# Anomaly detected in case '99910'.
# Anomaly detected in case '99911'.
# Anomaly detected in case '99912'.
# Anomaly detected in case '99913'.
# Case '99914' is compliant.
# Anomaly detected in case '99915'.
# Anomaly detected in case '99916'.
# Case '99917' is compliant.
# Anomaly detected in case '99918'.
# Anomaly detected in case '99919'.
# Anomaly detected in case '99920'.
# Anomaly detected in case '99921'.
# Anomaly detected in case '99922'.
# Anomaly detected in case '99923'.
# Anomaly detected in case '99924'.
# Anomaly detected in case '99925'.
# Case '99926' is compliant.
# Case '99927' is compliant.
# Anomaly detected in case '99928'.
# Case '99929' is compliant.
# Case '99930' is compliant.
# Anomaly detected in case '99931'.
# Anomaly detected in case '99932'.
# Case '99933' is compliant.
# Anomaly detected in case '99934'.
# Case '99935' is compliant.
# Anomaly detected in case '99936'.
# Anomaly detected in case '99937'.
# Case '99938' is compliant.
# Case '99939' is compliant.
# Case '99940' is compliant.
# Case '99941' is compliant.
# Anomaly detected in case '99942'.
# Anomaly detected in case '99943'.
# Anomaly detected in case '99944'.
# Anomaly detected in case '99945'.
# Anomaly detected in case '99946'.
# Case '99947' is compliant.
# Case '99948' is compliant.
# Anomaly detected in case '99949'.
# Anomaly detected in case '99950'.
# Case '99951' is compliant.
# Anomaly detected in case '99952'.
# Case '99953' is compliant.
# Anomaly detected in case '99954'.
# Anomaly detected in case '99955'.
# Anomaly detected in case '99956'.
# Anomaly detected in case '99957'.
# Case '99958' is compliant.
# Anomaly detected in case '99959'.
# Anomaly detected in case '99960'.
# Anomaly detected in case '99961'.
# Anomaly detected in case '99962'.
# Case '99963' is compliant.
# Case '99964' is compliant.
# Case '99965' is compliant.
# Anomaly detected in case '99966'.
# Case '99967' is compliant.
# Anomaly detected in case '99968'.
# Anomaly detected in case '99969'.
# Case '99970' is compliant.
# Anomaly detected in case '99971'.
# Anomaly detected in case '99972'.
# Anomaly detected in case '99973'.
# Case '99974' is compliant.
# Case '99975' is compliant.
# Case '99976' is compliant.
# Case '99977' is compliant.
# Case '99978' is compliant.
# Anomaly detected in case '99979'.
# Anomaly detected in case '99980'.
# Anomaly detected in case '99981'.
# Anomaly detected in case '99982'.
# Anomaly detected in case '99983'.
# Anomaly detected in case '99984'.
# Anomaly detected in case '99985'.
# Anomaly detected in case '99986'.
# Anomaly detected in case '99987'.
# Anomaly detected in case '99988'.
# Anomaly detected in case '99989'.
# Anomaly detected in case '99990'.
# Anomaly detected in case '99991'.
# Anomaly detected in case '99992'.
# Anomaly detected in case '99993'.
# Case '99994' is compliant.
# Case '99995' is compliant.
# Anomaly detected in case '99996'.
# Anomaly detected in case '99997'.
# Anomaly detected in case '99998'.
# Anomaly detected in case '99999'.
# Case '100000' is compliant.
# Total cases: 100000
# Compliant cases: 22373 (22.37%)
# Non-compliant cases: 77627 (77.63%)
# Summary saved to data/alpha_SP_DF_cleaned_SP_DF_cleaned_summary.json
# Compliant cases saved to alpha_SP_DF_cleaned_SP_DF_cleaned_compliant.csv
# Non-compliant cases saved to alpha_SP_DF_cleaned_SP_DF_cleaned_non_compliant.csv
# Petri Net model saved as PNG at: alpha_SP_DF_cleaned_SP_DF_cleaned.png
