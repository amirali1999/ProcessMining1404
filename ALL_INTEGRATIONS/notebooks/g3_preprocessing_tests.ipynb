# %%
import os, sys
from pathlib import Path
import prefixspan
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

BASE_DIR = Path(
    r"D:/2-MScSoftware/University/Courses/ProcessMining/projects/ProcessMining1404/ALL_INTEGRATIONS"
)

# 🚫 پاک‌سازی کامل مسیرهای خطرناک
sys.path = [
    p for p in sys.path
    if "Group7" not in p and "process_mining_core" not in p
]

# ✅ فقط پروژه اصلی
sys.path.insert(0, str(BASE_DIR))

os.environ["DJANGO_SETTINGS_MODULE"] = "config.settings"

import django
django.setup()

# %%
from preprocessing import services
df_raw = services.get_event_log_dataframe(1, "raw")
df_raw.head()
# Out:
# ---------------------------------------------------------------------------
# DoesNotExist                              Traceback (most recent call last)
# File D:\2-MScSoftware\University\Courses\ProcessMining\projects\ProcessMining1404\ALL_INTEGRATIONS\preprocessing\services.py:46, in get_event_log_dataframe(event_log_id, version)
#      45 try:
# ---> 46     event_log = EventLog.objects.select_related("uploaded_file").get(pk=event_log_id)
#      47 except EventLog.DoesNotExist:
#
# File D:\2-MScSoftware\University\Courses\ProcessMining\projects\ProcessMining1404\ALL_INTEGRATIONS\.venv\Lib\site-packages\django\db\models\query.py:639, in QuerySet.get(self, *args, **kwargs)
#     638 if not num:
# --> 639     raise self.model.DoesNotExist(
#     640         "%s matching query does not exist." % self.model._meta.object_name
#     641     )
#     642 raise self.model.MultipleObjectsReturned(
#     643     "get() returned more than one %s -- it returned %s!"
#     644     % (
# ...

# %%
df_raw = services.get_event_log_dataframe(
    event_log_id=1,
    version="raw"
)

df_raw.head()
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_raw = services.get_event_log_dataframe(
#       2     event_log_id=1,
#       3     version="raw"
#       4 )
#       6 df_raw.head()
#
# File D:\2-MScSoftware\University\Courses\ProcessMining\projects\ProcessMining1404\ALL_INTEGRATIONS\preprocessing\services.py:46, in get_event_log_dataframe(event_log_id, version)
#      43 from uploads.models import EventLog
#      45 try:
# ---> 46     event_log = EventLog.objects.select_related("uploaded_file").get(pk=event_log_id)
#      47 except EventLog.DoesNotExist:
#      48     raise ValueError(f"EventLog with id={event_log_id} not found")
#
# File D:\2-MScSoftware\University\Courses\ProcessMining\projects\ProcessMining1404\ALL_INTEGRATIONS\.venv\Lib\site-packages\django\db\models\query.py:635, in QuerySet.get(self, *args, **kwargs)
# ...
